# %% [markdown]
# # El Lab (DAA Project)
#
# En un laboratorio de la BIOFAM quieren modificar genéticamente una gallina para que sea más resistente a las enfermedades. Para esto deben de cambiar la secuencia de aminoácidos presentes en su genoma. La secuencia que quieren reproducir es la de los cocodrilos, que se sabe que son animales que han existido por millones de años. Entonces, dado que una secuencia de aminoácidos se puede codificar como una secuencia de caracteres se tiene:
#
# - $T$ es la secuencia de aminoácidos de los cocodrilos (tamaño $m$)
# - $S$ es la secuencia de aminoácidos de la gallina original (tamaño $n$)
# - $A$ es la secuencia de aminoácidos de la galllina a crear (inicialmente vacía)
#
# Para lograr que la gallina modificada adquiera la resistencia de un cocodrilo se sabe que su secuencia de aminoácidos $A$, debe contener como prefijo a $T$. Como en la BIOFAM hubo recortes de presupuesto solo cuentan con una máquina que puede hacer dos modificaciones genéticas:
# 1. Extrae y elimina el primer aminoácido de $S$ y lo coloca al principio de $A$
# 2. Extrae y elimina el primer aminoácido de $S$ y lo coloca al final de $A$
#
# Encuentre la **cantidad de secuencias de operaciones posibles** tales que la gallina genéticamente modificada sea resistente a las enfermedades.
#
# Aclaraciones del problema:
# + Se debe modificar la gallina ($A$) con todos los caracteres de $S$, no basta con solo tener el prefijo, se debe llegar al final.

# %% [markdown]
# ## Soluciones
# Para una primera solución se realizó un algoritmo en el que se hace un backtrack por cada una de las operaciones posibles para crear la cadena $A$ comprobando finalmente si contiene a la cadena $T$ como prefijo dando como resultado una secuencia posible de operaciones.

# %%
def count_backtrack(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return backtrack(T, S, 0, "")
    return 0

# %% [markdown]
# Probando el algoritmo con distintos casos se obtiene como resultado:

# %%
print(count_backtrack('ACAC','ACACBCA'))
print(count_backtrack('ABAB','BABA'))
print(count_backtrack('ACABD','ACABDBCACA'))
print(count_backtrack('DBACA', 'ACABD'))
print(count_backtrack('AABBAA','BABAAA'))
print(count_backtrack('AABBAA','CHAABBAA'))
print(count_backtrack('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para el ejemplo donde $T$ (prefijo) es "ABAB" y la cadena $S$ es BABA se tiene:
# 1. B $\rightarrow$ BA $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
# 2. B $\rightarrow$ AB $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
#
# *Resultado*: 4

# %% [markdown]
# Se puede apreciar que, aunque el algoritmo resuelve el problema presenta una gran complejidad temporal, la ventaja radica en que para próximos algoritmos que tengan menor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto. Se conoce que $|T| = m$ y $|S| = n$, por tanto:
#
# \begin{equation*}
#     T(n,m) = 2 T(n-1) + 1
# \end{equation*}
#
# donde por Teorema Maestro pertence a $\theta(2^n)$

# %% [markdown]
# Se puede observar que la primera letra colocándola al principio o al final genera exactamente la misma ramificación, por lo que sería mejor evitar hacer esta segunda ramificación innecesariamente, para ello:

# %%
def count_backtrack_modified(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando este algoritmo obtenemos los mismmos resultados, con una ligera mejora en eficiencia:

# %%
print(count_backtrack_modified('ACAC','ACACBCA'))
print(count_backtrack_modified('ACAC','CACA'))
print(count_backtrack_modified('ACABD','ACABDBCACA'))
print(count_backtrack_modified('DBACA', 'ACABD'))
print(count_backtrack_modified('AABBAA','BABAAA'))
print(count_backtrack_modified('AABBAA','CHAABBAA'))
print(count_backtrack_modified('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Como propuesta para una mejor solución a lo anterior, se realizó un memoize ya que en algunos llamados se hacían cálculos sobre subcadenas que ya se habían realizado con anterioridad, por lo que sería mejor guardar por subsecuencias de la cadena formada $A$, la subcadena restante de $S$, así como la cantidad de subsecuencias de operaciones posibles realizadas.

# %%
def count_backtrack_memoize(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        memoize = {}
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            dict_str = S[index+1:len(S)]
            word_form = char + A
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant = memoize[dict_str][word_form]
            else: 
                cant = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant}
            word_form = A + char
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant += memoize[dict_str][word_form]
            else:
                cant2 = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant2}
                cant += cant2
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_backtrack_memoize('ACAC','ACACBCA'))
print(count_backtrack_memoize('ABAB','BABA'))
print(count_backtrack_memoize('ACABD','ACABDBCACA'))
print(count_backtrack_memoize('DBACA', 'ACABD'))
print(count_backtrack_memoize('AABBAA','BABAAA'))
print(count_backtrack_memoize('AABBAA','CHAABBAA'))
print(count_backtrack_memoize('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Aunque este algoritmo constituye una mejora significativa, sigue presentando una complejidad temporal excesiva, ya que en el peor de los casos no se repiten patrones (subcadenas) y por tanto sigue perteneciendo a $O(2^n)$ con una complejidad espacial superior. La ventaja radica en que para próximos algoritmos que tengan mejor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto.

# %% [markdown]
# Fue necesario encontrar otras vías para solucionar el ejercicio. Partiremos de los posibles casos en que puede aparecer la cadena $T$ (el prefijo), en la cadena creada (genéticamente modificada) $A$.
#
# Si se comienza a leer la cadena que se desea modificar desde atrás hacia adelante se puede observar que:
# + El último elemento podría ser colocado hacia adelante si dicho caracter es igual al primer elemento del prefijo dado que luego de él no se va a poder colocar ningún otro elemento en la cadena.
#     + A partir de este momento, el problema se reduce a calcular la cantidad de secuencias de operaciones en la que se puede formar un genoma modificado desde el inicio de la cadena hasta el caracter anterior a este elemento y el prefijo desde el segundo elemento hasta el final:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1} p_1)$ $\rightarrow$ $method(p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + El último elemento igualmente siempre se puede poner detrás
#     + Si no pertence al prefijo, el problema se reduce a generar una secuencia de operaciones tal que se obtenga una cadena a partir del resto de esta (sin dicho elemento) teniendo en cuenta todo el prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... a_j)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + De igual forma este caracter se puede considerar poner detrás, pero si pertence al prefijo entonces debe ser el último elemento del mismo ya que es el último que se coloca, siendo el tamaño del prefijo igual al de la cadena
#     + Este problema se reduce a generar con el resto de la cadena el resto del prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... p_i)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_{i-1}~~~~y~~~~a_1 a_2 ... a_{j-1})$

# %%
def count_naive_recursive(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def naive_recursive(S,T):
            if len(S) < len(T): return 0
            if len(S)==1: 
                if len(T)==1 and T[0]==S[0]: return 2
                return 0
            if len(T)==0 : return 0
            output = naive_recursive(S[0:len(S)-1],T)
            if S[-1]==T[0]: 
                if len(T)==1: output += 2**(len(S)-1)
                else: output += naive_recursive(S[0:len(S)-1],T[1:])
            if len(S)==len(T) and S[-1]==T[-1]: output += naive_recursive(S[0:len(S)-1],T[0:len(T)-1])
            return output
        return naive_recursive(S,T)
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_naive_recursive('ACAC','ACACBCA'))
print(count_naive_recursive('ABAB','BABA'))
print(count_naive_recursive('ACABD','ACABDBCACA'))
print(count_naive_recursive('DBACA', 'ACABD'))
print(count_naive_recursive('AABBAA','BABAAA'))
print(count_naive_recursive('AABBAA','CHAABBAA'))
print(count_naive_recursive('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para este algoritmo se hizo uso de dp guardando los resultados de los cálculos anteriores siguiendo el flujo del algoritmo anterior con sus 3 índices.
# Por lo que este algoritmo pertenece a $O(n^2*m)$

# %%
def count_dynamic(T:str, S:str):
    if len(T) > len(S): return 0
    dp=[ [ [0 for i in range(len(S))] for i in range(len(T))] for i in range(len(T)) ]
    i=len(T)-1
    while i>=0:
        for j in range(i,len(T)):
            for k in range(len(S)):
                m=j-i
                if m > k:
                    dp[i][j][k]=0
                    continue
                if k==0:
                    if S[0] == T[i]: dp[i][j][k]=2
                    else: dp[i][j][k]=0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
                    continue
                if k >0 : dp[i][j][k]=dp[i][j][k-1]
                if S[k] == T[i]:
                    if m==0: dp[i][j][k]+=2**k
                    elif i<len(T)-1 and k>0: dp[i][j][k]+=dp[i+1][j][k-1]
                if k==m and S[k] == T[j] and j>0 and k>0: dp[i][j][k]+=dp[i][j-1][k-1]
        i-=1
    return dp[0][len(T)-1][len(S)-1]

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_dynamic('ACAC','ACACBCA'))
print(count_dynamic('ABAB','BABA'))
print(count_dynamic('ACABD','ACABDBCACA'))
print(count_dynamic('DBACA', 'ACABD'))
print(count_dynamic('AABBAA','BABAAA'))
print(count_dynamic('AABBAA','CHAABBAA'))
print(count_dynamic('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Explicaciones del nuevo algoritmo!!!

# %%
# Nuevo codigo

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
# Probando el codigo

# %% [markdown]
# En las siguientes líneas de código se realizó un generador de cadenas que juegan el rol de prefijo (cocodrilo) y genoma a modificar (gallina) haciendo particiones en el prefijo, insertando un caracter random en alguna partición e invirtiendo la secuencia. Se comprueban los resultados entre los algoritmos.

# %%
import random
VOC = ["C","T","G","A","U","R","D"]

def generate_prefix(a=10,b=15):
    length = random.randint(a, b)
    prefix = ""
    while length > 0:
        letter = random.randint(0, len(VOC)-1)
        pos = random.randint(0,1)
        if pos:
            prefix += VOC[letter]
        else:
            prefix = VOC[letter] + prefix
        length-=1
    return prefix

def generate_secuence(prefix:str):
    secuence = ""
    while len(secuence) < 40:
        letter = random.randint(0, len(VOC)-1)
        partition = list(prefix.partition(random.choice(prefix)))
        pos = random.randint(0,len(partition))
        partition.insert(pos, VOC[letter])
        secuence += "".join(reversed(partition))
        secuence
    return secuence
   
TEST = 1
while TEST <= 100:
    print(f'TEST NO. {TEST}')
    prefix = generate_prefix()
    secuence = generate_secuence(prefix)
    print(f'PREFIX: {prefix} \nSECUENCE: {secuence}')
    #c_back = count_backtrack_memoize(prefix,secuence)
    #print(f'Naive Recursive: {c_back}')
    c_naive = count_naive_recursive(prefix,secuence)
    print(f'Naive Recursive: {c_naive}')
    c_dyn = count_dynamic(prefix,secuence)
    print(f'Naive Recursive: {c_dyn}')
    print()
    ##assert c_back == c_naive == c_dyn
    assert c_naive == c_dyn
    TEST+=1
# Out:
# TEST NO. 1
# PREFIX: DCUACDTGARAR
# SECUENCE: CUACDTGARARDCCDTGARARTADCUACDTGARARGUDCARRDCUACDTGAA
# Naive Recursive: 14
# Naive Recursive: 14
#
# TEST NO. 2
# PREFIX: TRADGUDGCA
# SECUENCE: ACCTRADGUDGGUDGCADTRAAUDGCACGTRADDGUDGCAARTR
# Naive Recursive: 584
# Naive Recursive: 584
#
# TEST NO. 3
# PREFIX: RRDUGUDGUUTDUT
# SECUENCE: GUDGUUTDUTUDRRDGUDGUUTDUTUARRDGUDGUUTDUTUCRRD
# Naive Recursive: 158
# Naive Recursive: 158
#
# TEST NO. 4
# PREFIX: RUUDACCATCCADDD
# SECUENCE: UDACCATCCADDDUCRTACCATCCADDDDRUUACCATCCADDDDRUUC
# Naive Recursive: 10
# Naive Recursive: 10
#
# TEST NO. 5
# PREFIX: CDRGCGAUAGDU
# SECUENCE: CGAUAGDUGCDRCACGAUAGDUGCDRGCGAUAGDURCDCDRGCGAUAGDUGC
# Naive Recursive: 13660
# Naive Recursive: 13660
#
# TEST NO. 6
# PREFIX: RATRACGAGG
# SECUENCE: TRACGAGGACRTRACGAGGADRAGGGRATRACUATRACGAGGTR
# Naive Recursive: 70
# Naive Recursive: 70
#
# TEST NO. 7
# PREFIX: CTDCAUTACT
# SECUENCE: ADCAUTACTTCDCAUTACTTTCDCAUTACTTGCTDCAUTACTTC
# Naive Recursive: 91392
# Naive Recursive: 91392
#
# TEST NO. 8
# PREFIX: AUGRCDCUDGRD
# SECUENCE: GRCDCUDGRDUAARCDCUDGRDGAUGCUDGRDDDAUGRCCUDGRDDAUGRCR
# Naive Recursive: 28
# Naive Recursive: 28
#
# TEST NO. 9
# PREFIX: GRDGCDARDUART
# SECUENCE: ARTRUGRDGCDARDRDUARTATGRDGCDARTRUGRDGCDARD
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 10
# PREFIX: DCGGTRDATGCA
# SECUENCE: TGCATADCGGTRDCCGGTRDATGCADRTGCAADCGGTRDGTRDATGCAGGDC
# Naive Recursive: 12694
# Naive Recursive: 12694
#
# TEST NO. 11
# PREFIX: ACGAADUUTT
# SECUENCE: UUTTTDACGAARTTACGAADUUUUTTDACGAAUUUTTDRACGAA
# Naive Recursive: 336
# Naive Recursive: 336
#
# TEST NO. 12
# PREFIX: RGADTURARRGCCA
# SECUENCE: CACGRGADTURARRGDTURARRGCCAARGUTCACRGADTURARRG
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 13
# PREFIX: AGTCUCGDGUGDD
# SECUENCE: TCUCGDGUGDDAGAGUGDDDAGTCUCGAGUGDDDRAGTCUCG
# Naive Recursive: 32
# Naive Recursive: 32
#
# TEST NO. 14
# PREFIX: CGGTGDGCTD
# SECUENCE: TGTGDGCTDGCGTGDGCTDGCUGGTGDGCTDRCGGTGDGCTDCD
# Naive Recursive: 1233120
# Naive Recursive: 1233120
#
# TEST NO. 15
# PREFIX: AGAAUUUGGR
# SECUENCE: AAUUUGGRDGARAAGAAUUUGGGAAUUUGGRRATUUGGRUAGAA
# Naive Recursive: 36820
# Naive Recursive: 36820
#
# TEST NO. 16
# PREFIX: CDDARDGCUA
# SECUENCE: AUCDDARDGCGDARDGCUADCDRDGCUAAACDDDDARDGCUACU
# Naive Recursive: 2652
# Naive Recursive: 2652
#
# TEST NO. 17
# PREFIX: CGCDUURRACAT
# SECUENCE: CATARCGCDUURRGCDUURRACATCGCDUURRACATUGCGCDUURRACATCD
# Naive Recursive: 60
# Naive Recursive: 60
#
# TEST NO. 18
# PREFIX: RGAUCDGGGCRCTUU
# SECUENCE: ADGGGCRCTUUCRGAUGAUCDGGGCRCTUURAAUCDGGGCRCTUUGTR
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 19
# PREFIX: GUUACRCDTDGCT
# SECUENCE: DGCTTGUUACRCDTTDGCTDGUUACRCURRCDTDGCTCGUUA
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 20
# PREFIX: TTDTTTUATCRTGTT
# SECUENCE: TDTTTUATCRTGTTTTTDTTTUATCRTGTTTRTDTTTUATCRTGTTGT
# Naive Recursive: 176
# Naive Recursive: 176
#
# TEST NO. 21
# PREFIX: GRGADUGGDRT
# SECUENCE: UGGDRTDGRGAUTTGRGADUGGDRRGADUGGDRTUGRGADUGGDRTTG
# Naive Recursive: 74786
# Naive Recursive: 74786
#
# TEST NO. 22
# PREFIX: TTDDACACATU
# SECUENCE: TDDACACATUUTCTDDACACATUTCACATURATTDDCACATUCATTDD
# Naive Recursive: 331796
# Naive Recursive: 331796
#
# TEST NO. 23
# PREFIX: ADCTDDCTDCG
# SECUENCE: CTDDCTDCGCDAGTDDCTDCGCADCTDDCTDCGTDACTDDCTDCGDCA
# Naive Recursive: 43940918
# Naive Recursive: 43940918
#
# TEST NO. 24
# PREFIX: ACUDCTRGDGGRA
# SECUENCE: CUDCTRGDGGRAAUGDGGRARACUDCTUUDCTRGDGGRARCA
# Naive Recursive: 12
# Naive Recursive: 12
#
# TEST NO. 25
# PREFIX: TGDCDCRTCU
# SECUENCE: TCUGRTGDCDCTCURTGDCDCTDCDCRTCUDTGGUTGDCDCRTC
# Naive Recursive: 2190
# Naive Recursive: 2190
#
# TEST NO. 26
# PREFIX: UDUGARRRTDGATAA
# SECUENCE: DGATAATRUDUGARRRRUGARRRTDGATAADURRRTDGATAAAUDUGA
# Naive Recursive: 436
# Naive Recursive: 436
#
# TEST NO. 27
# PREFIX: AGUTUGTDDRC
# SECUENCE: DRCDAGUTUGTDDRCDAGUTUGTAUTUGTDDRCGAUTUGTDDRCUAGA
# Naive Recursive: 2076
# Naive Recursive: 2076
#
# TEST NO. 28
# PREFIX: TCGUTDUTUCTUUT
# SECUENCE: TDUTUCTUUTUATCGRCGUTDUTUCTUUTTCGUTDUTUCTUUTCT
# Naive Recursive: 136
# Naive Recursive: 136
#
# TEST NO. 29
# PREFIX: ARDTURAGGRRARC
# SECUENCE: GRRARCUGARDTURATDTURAGGRRARCRADTURAGGRRARCRAU
# Naive Recursive: 102
# Naive Recursive: 102
#
# TEST NO. 30
# PREFIX: CCCCDRGAAUUT
# SECUENCE: TCCCDRGAAUUTCAUUTACCCCCDRGCCCDRGAAUUTCUGAAUUTRCCCCDG
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 31
# PREFIX: DURACRGCTRTDC
# SECUENCE: URACRGCTRTDCDCCRTDCTDURACRGCACRGCTRTDCRCDU
# Naive Recursive: 10
# Naive Recursive: 10
#
# TEST NO. 32
# PREFIX: ARTUUATRDT
# SECUENCE: UUATRDTUTARTDRARTUUATRUUATRDTTTARUUATRDTGTAR
# Naive Recursive: 156632
# Naive Recursive: 156632
#
# TEST NO. 33
# PREFIX: DTCRCTCGCGA
# SECUENCE: CGAGDTCRCTCACGAGDTCRCTCGCGAGRDTCRCTCRCTCGCGACDTC
# Naive Recursive: 1021460
# Naive Recursive: 1021460
#
# TEST NO. 34
# PREFIX: TATTGGGDDGAAAG
# SECUENCE: ATTGGGDDGAAAGCTGGDDGAAAGGTTATTUGGDDGAAAGGTATT
# Naive Recursive: 73960
# Naive Recursive: 73960
#
# TEST NO. 35
# PREFIX: GCGDGUGCGCUA
# SECUENCE: CGDGUGCGCUAGADCGDGUGCGCUAGGDGUGCGCUACCGUGUGCGCUADGCG
# Naive Recursive: 354922528
# Naive Recursive: 354922528
#
# TEST NO. 36
# PREFIX: CACGDCCGRTRGD
# SECUENCE: TRGDRRCACGDCCGDCCGRTRGDGDCACCCGRTRGDUDCACG
# Naive Recursive: 520
# Naive Recursive: 520
#
# TEST NO. 37
# PREFIX: UTGGCGTTGAC
# SECUENCE: TGGCGTTGACDUGCGTTGACDGUTCDAUTGGCGTTGGTTGACCUTGGA
# Naive Recursive: 107592
# Naive Recursive: 107592
#
# TEST NO. 38
# PREFIX: DDUTURGACGGGDGT
# SECUENCE: GACGGGDGTGRDDUTUURGACGGGDGTTDDUAURGACGGGDGTCTDDU
# Naive Recursive: 144
# Naive Recursive: 144
#
# TEST NO. 39
# PREFIX: CTURGRATGDT
# SECUENCE: URGRATGDTDTCRGRATGDTUCTRURGRATGDTTACCTGDTACTURGR
# Naive Recursive: 54
# Naive Recursive: 54
#
# TEST NO. 40
# PREFIX: GACCDDDDDCDTD
# SECUENCE: DDDDCDTDDRGACCCDDDDDCDTDACGADDDDCDTDDGACCT
# Naive Recursive: 1072
# Naive Recursive: 1072
#
# TEST NO. 41
# PREFIX: ADUCRTDRCC
# SECUENCE: RTDRCCCTADUTDRCCDRADUCRTDRCCCTADUGTDRCCRADUC
# Naive Recursive: 50530
# Naive Recursive: 50530
#
# TEST NO. 42
# PREFIX: DUUACGACTRAU
# SECUENCE: CRAUTDUUACGACAURUDUUACGACTRUACGACTRAUUDGACTRAUCRDUUA
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 43
# PREFIX: GUTDGATTACU
# SECUENCE: UCGUTDGATTAUTDGATTACUUAGTTACUAGUTDGUUTDGATTACUTG
# Naive Recursive: 30682
# Naive Recursive: 30682
#
# TEST NO. 44
# PREFIX: CRCTGGDDCCDDR
# SECUENCE: ADCCDDRDCRCTGGGDDCCDDRGCRCTUCTGGDDCCDDRCRC
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 45
# PREFIX: CUDCGACGGUTUA
# SECUENCE: CGGUTUACACUDCGUATACUDCGACGGUUDCGACGGUTUACR
# Naive Recursive: 40
# Naive Recursive: 40
#
# TEST NO. 46
# PREFIX: AUARGRGAUCGRAUR
# SECUENCE: CRGAUCGRAURGAUARUARGRGAUCGRAURADRGAUCGRAURGCAUAR
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 47
# PREFIX: DGGUTCRRUCATC
# SECUENCE: GUTCRRUCATCGCDTCRRUCATCURDGGTCRRUCATCUDGGA
# Naive Recursive: 10
# Naive Recursive: 10
#
# TEST NO. 48
# PREFIX: TAAUGDDATAUT
# SECUENCE: AAUGDDATAUTTUAUGDDATAUTTATAUGDDATAUTATRAUGDDATAUTAGT
# Naive Recursive: 48
# Naive Recursive: 48
#
# TEST NO. 49
# PREFIX: CATUDUDTGCCTDUG
# SECUENCE: DUDTGCCTDUGUDCATATUDUDTGCCTDUGCTDUDTGCCTDUGDCATU
# Naive Recursive: 24
# Naive Recursive: 24
#
# TEST NO. 50
# PREFIX: ADRGUCTDARR
# SECUENCE: GUCTDARRRRADGUCTDARRRDADADARRTADRGUCDRGUCTDARRTA
# Naive Recursive: 442
# Naive Recursive: 442
#
# TEST NO. 51
# PREFIX: CUAUDDRRRCAGA
# SECUENCE: RRCAGARCUAUDDTARGCUAUDDRRRCAAUDDRRRCAGACUC
# Naive Recursive: 168
# Naive Recursive: 168
#
# TEST NO. 52
# PREFIX: TTDADRRGDCURGAC
# SECUENCE: RGDCURGACRDTTDADDCURGACDGTTDADRRRGDCURGACRUTTDAD
# Naive Recursive: 188
# Naive Recursive: 188
#
# TEST NO. 53
# PREFIX: ARCDRTDRTGGTU
# SECUENCE: GDRTGGTUTARCDRADRTDRTGGTUCARRTDRTGGTUDCARC
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 54
# PREFIX: TGUDGARTRAUUT
# SECUENCE: TRAUUTTRTGUDGADGARTRAUUTURTGGUDGARTRAUUTTU
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 55
# PREFIX: AUGDDUTCCCACAR
# SECUENCE: DUTCCCACARADAUGGDDUTCCCACARUAAGCCACARCAUGDDUT
# Naive Recursive: 48
# Naive Recursive: 48
#
# TEST NO. 56
# PREFIX: CUARRGGRRRRGAA
# SECUENCE: RRGGRRRRGAAADCUUARRGGRRRRGAACGRGGRRRRGAARCUAA
# Naive Recursive: 336
# Naive Recursive: 336
#
# TEST NO. 57
# PREFIX: RUDGRRDGUTU
# SECUENCE: UDGRRDGUTUDRDGRRDGUTUDURUDGRRDGUTURCGRRDGUTUDURU
# Naive Recursive: 2394474
# Naive Recursive: 2394474
#
# TEST NO. 58
# PREFIX: RUCTGGADUDRU
# SECUENCE: CTGGADUDRUURGCTGGADUDRUTURTGGADUDRUCRUCTGGADUDRUDCRU
# Naive Recursive: 84
# Naive Recursive: 84
#
# TEST NO. 59
# PREFIX: AADAGCCDGCATUGG
# SECUENCE: ADAGCCDGCATUGGAAADAGCCDGCATUGGAUADAGCCDGCATUGGRA
# Naive Recursive: 40
# Naive Recursive: 40
#
# TEST NO. 60
# PREFIX: DACDDCDAAUG
# SECUENCE: CDDCDAAUGARDDCDDCDAAUGADDDCDAAUGACDACGDACDDCDAAU
# Naive Recursive: 252
# Naive Recursive: 252
#
# TEST NO. 61
# PREFIX: ADRARRUCATGCCDU
# SECUENCE: DRARRUCATGCCDUAAUARRUCATGCCDURADARRUCATGCCDURRAD
# Naive Recursive: 16
# Naive Recursive: 16
#
# TEST NO. 62
# PREFIX: RUDTCCUTRR
# SECUENCE: UDTCCUTRRRAUDTCCUTRRURUDTCCUTRRURUDTCCUTRRRA
# Naive Recursive: 7704
# Naive Recursive: 7704
#
# TEST NO. 63
# PREFIX: CGRGDRUCCGDCAAG
# SECUENCE: GDRUCCGDCAAGRCGCARGDRUCCGDCAAGGCACCGDCAAGUCGRGDR
# Naive Recursive: 164
# Naive Recursive: 164
#
# TEST NO. 64
# PREFIX: ACGAUCCGGGCGTG
# SECUENCE: AUCCGGGCGTGGDACAUCCGGGCGTGGACAAGAUCCGGGCGTGCA
# Naive Recursive: 266
# Naive Recursive: 266
#
# TEST NO. 65
# PREFIX: TADCATTUCGDC
# SECUENCE: CATTUCGDCGDTADCGTADCATTUCUAATTUCGDCCTADGATTUCGDCCTAD
# Naive Recursive: 224
# Naive Recursive: 224
#
# TEST NO. 66
# PREFIX: AGCATGGUGUUCCTU
# SECUENCE: GUUCCTUUUAGCATGGAATGGUGUUCCTUCAGCGUUCCTUUAGCATGG
# Naive Recursive: 540
# Naive Recursive: 540
#
# TEST NO. 67
# PREFIX: TUDAUDCCRTTTCRD
# SECUENCE: CRTTTCRDCTUDAUDGAUDCCRTTTCRDDDTUUDCCRTTTCRDRATUD
# Naive Recursive: 64
# Naive Recursive: 64
#
# TEST NO. 68
# PREFIX: GCACTGTGUARC
# SECUENCE: CTGTGUARCAGCDCACTGTGUARCDGTACTGTGUARCCGACTGTGUARCCGG
# Naive Recursive: 612
# Naive Recursive: 612
#
# TEST NO. 69
# PREFIX: TCRTADCGCRTAGDG
# SECUENCE: CRTADCGCRTAGDGCTRRTADCGCRTAGDGCTCRTADCGCRTAGDGDT
# Naive Recursive: 14
# Naive Recursive: 14
#
# TEST NO. 70
# PREFIX: CGUCRCCUCG
# SECUENCE: GUCRCCUCGCAAGUCRCCUCGCTCCUCGRCGUCGUCRCCUCGCA
# Naive Recursive: 319731728
# Naive Recursive: 319731728
#
# TEST NO. 71
# PREFIX: DCTRUGAACUU
# SECUENCE: RCTRUGAACUUDTRUGAACUUCRDCTRUGAACUUDGGAACUUAUDCTR
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 72
# PREFIX: UDADTRCCCAT
# SECUENCE: ADADTRCCCATUCCATCCUDADTRRCCCATTRUDADDTRCCCATAUDG
# Naive Recursive: 512
# Naive Recursive: 512
#
# TEST NO. 73
# PREFIX: DAGCRCTRUCU
# SECUENCE: CTRUCURDAGCTCUUDAGCRCTRURCTRUCUCTDAGGCRCTRUCUADA
# Naive Recursive: 1396
# Naive Recursive: 1396
#
# TEST NO. 74
# PREFIX: DTTCTUDGDRDCAA
# SECUENCE: UTTCTUDGDRDCAADUAADTTCTUDGDRDCADGDRDCAAUDTTCT
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 75
# PREFIX: DRCGCTDTUUTTTDD
# SECUENCE: TDTUUTTTDDTDRCGCGCTDTUUTTTDDCDRCRCGCTDTUUTTTDDDA
# Naive Recursive: 272
# Naive Recursive: 272
#
# TEST NO. 76
# PREFIX: RRGDTADTGGCGCGC
# SECUENCE: DTADTGGCGCGCGRRUCADTGGCGCGCTRRGDGRGDTADTGGCGCGCR
# Naive Recursive: 82
# Naive Recursive: 82
#
# TEST NO. 77
# PREFIX: GGCAGRTARA
# SECUENCE: AGRTARAGCGGGRTARARAGGCGCAGRTARAGGGRTARAAGGCR
# Naive Recursive: 204
# Naive Recursive: 204
#
# TEST NO. 78
# PREFIX: DACRGTUTUDC
# SECUENCE: RGTUTUDCRCDAUTUDCTDACRGRDTUTUDCGDACRACRGTUTUDCDU
# Naive Recursive: 3910
# Naive Recursive: 3910
#
# TEST NO. 79
# PREFIX: GRDRDADAGUURUC
# SECUENCE: RDADAGUURUCDRGRDAGUURUCUAGRDRDRRDADAGUURUCDGR
# Naive Recursive: 94
# Naive Recursive: 94
#
# TEST NO. 80
# PREFIX: GACADRURTA
# SECUENCE: CADRURTAADGCADRURTAAGACADRURTAAGTUCADRURTAAG
# Naive Recursive: 68
# Naive Recursive: 68
#
# TEST NO. 81
# PREFIX: RDDTGDUUATT
# SECUENCE: DTGDUUATTDRDDUUATTRGRDDTTTTARDDTGDUUAUATTURDDTGD
# Naive Recursive: 40
# Naive Recursive: 40
#
# TEST NO. 82
# PREFIX: TCTRTGRUUDRD
# SECUENCE: AUDRDUTCTRTGRTRTGRUUDRDCTDRUUDRDGGTCTRTUCTRTGRUUDRDT
# Naive Recursive: 25170096
# Naive Recursive: 25170096
#
# TEST NO. 83
# PREFIX: AGDDRRRARAGRUU
# SECUENCE: RRRARAGRUURAGDDGDDRRRARAGRUUADRGDDRRRARAGRUUA
# Naive Recursive: 648
# Naive Recursive: 648
#
# TEST NO. 84
# PREFIX: ADURTTUCARGGART
# SECUENCE: TUCARGGARTDTADURDURTTUCARGGARTAGTUCARGGARTGTADUR
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 85
# PREFIX: URTADUDDCURURRC
# SECUENCE: DADUDDCURURRCTURUDDCURURRCDAURTACDUDDCURURRCAURT
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 86
# PREFIX: CDRGRATUCGGACTD
# SECUENCE: CRATUCGGACTDGCDRTUCGGACTDACDRGRDGRATUCGGACTDDRCD
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 87
# PREFIX: CACCCGAGCTRRG
# SECUENCE: RGRCACCCGAGCTTACCCGAGCTRRGCDCCCGAGCTRRGACC
# Naive Recursive: 1224
# Naive Recursive: 1224
#
# TEST NO. 88
# PREFIX: AUGCDAGUCR
# SECUENCE: RAUGCDAGUCDRAUGCDAGUCADAGUCRDAUGCUGCDAGUCRAR
# Naive Recursive: 234
# Naive Recursive: 234
#
# TEST NO. 89
# PREFIX: TDDDAUUATUTGDD
# SECUENCE: DDGTDDDAUUATUTUUATUTGDDUTDDDAAUATUTGDDUCTDDDA
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 90
# PREFIX: TGCCACUGDG
# SECUENCE: GCCACUGDGGTCACUGDGCRTGGDTGCCACUGDCACUGDGCRTG
# Naive Recursive: 2384
# Naive Recursive: 2384
#
# TEST NO. 91
# PREFIX: RRUGTRGCDTRU
# SECUENCE: TRGCDTRUGRRUTTRGCDTRUGURRUTRGCDTRUGTRRUGGTRGCDTRUURR
# Naive Recursive: 3010
# Naive Recursive: 3010
#
# TEST NO. 92
# PREFIX: UCCRDDTADDAG
# SECUENCE: RCRDDTADDAGCURGUCCRDDTADDADTADDAGUDUCCRCRDDTADDAGRCU
# Naive Recursive: 52224
# Naive Recursive: 52224
#
# TEST NO. 93
# PREFIX: ACAUAAGRCUART
# SECUENCE: CUARTRACAUAAGUCAUAAGRCUARTARTRCUARTGACAUAA
# Naive Recursive: 264
# Naive Recursive: 264
#
# TEST NO. 94
# PREFIX: DRUGUAUDRRGR
# SECUENCE: UAUDRRGRAGDRUUGUAUDRRGRURDUDRRGRACDRUGUUAUDRRGRGTDRU
# Naive Recursive: 14320512
# Naive Recursive: 14320512
#
# TEST NO. 95
# PREFIX: CTTDACADAAAGR
# SECUENCE: CACADAAAGRDCTTRCCTTDACADAAAGDCADAAAGRACTTD
# Naive Recursive: 0
# Naive Recursive: 0
#
# TEST NO. 96
# PREFIX: RCUACCRDDC
# SECUENCE: DCADRCUACCRTDCDRCUACCRDCDRCUACCRRCCCRDDCARCU
# Naive Recursive: 330
# Naive Recursive: 330
#
# TEST NO. 97
# PREFIX: AATCDDDDRTAAC
# SECUENCE: ATCDDDDRTAACRADDDRTAACDGAATCATCDDDDRTAACAR
# Naive Recursive: 18
# Naive Recursive: 18
#
# TEST NO. 98
# PREFIX: GRCGTACRDR
# SECUENCE: RCGTACRDRGUARCGTACRDRGCGTACRDRTRGRCGTACRDRGG
# Naive Recursive: 3208264
# Naive Recursive: 3208264
#
# TEST NO. 99
# PREFIX: CACRAUDTCAUA
# SECUENCE: TCAUADRCACRAUUACRAUDTCAUACCRAUDTCAUAAGCADTCAUAUCACRA
# Naive Recursive: 1308
# Naive Recursive: 1308
#
# TEST NO. 100
# PREFIX: UDADACUUTU
# SECUENCE: DACUUTUTAUDDADACUUTUUCDACUUTUTAUDDACUUTUADUD
# Naive Recursive: 2381806
# Naive Recursive: 2381806
