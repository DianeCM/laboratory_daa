# %% [markdown]
# # El Lab (DAA Project)
#
# En un laboratorio de la BIOFAM quieren modificar genéticamente una gallina para que sea más resistente a las enfermedades. Para esto deben de cambiar la secuencia de aminoácidos presentes en su genoma. La secuencia que quieren reproducir es la de los cocodrilos, que se sabe que son animales que han existido por millones de años. Entonces, dado que una secuencia de aminoácidos se puede codificar como una secuencia de caracteres se tiene:
#
# - $T$ es la secuencia de aminoácidos de los cocodrilos (tamaño $m$)
# - $S$ es la secuencia de aminoácidos de la gallina original (tamaño $n$)
# - $A$ es la secuencia de aminoácidos de la galllina a crear (inicialmente vacía)
#
# Para lograr que la gallina modificada adquiera la resistencia de un cocodrilo se sabe que su secuencia de aminoácidos $A$, debe contener como prefijo a $T$. Como en la BIOFAM hubo recortes de presupuesto solo cuentan con una máquina que puede hacer dos modificaciones genéticas:
# 1. Extrae y elimina el primer aminoácido de $S$ y lo coloca al principio de $A$
# 2. Extrae y elimina el primer aminoácido de $S$ y lo coloca al final de $A$
#
# Encuentre la **cantidad de secuencias de operaciones posibles** tales que la gallina genéticamente modificada sea resistente a las enfermedades.
#
# Aclaraciones del problema:
# + Se debe modificar la gallina ($A$) con todos los caracteres de $S$, no basta con solo tener el prefijo, se debe llegar al final.

# %% [markdown]
# ## Soluciones
# Para una primera solución se realizó un algoritmo en el que se hace un backtrack por cada una de las operaciones posibles para crear la cadena $A$ comprobando finalmente si contiene a la cadena $T$ como prefijo dando como resultado una secuencia posible de operaciones.

# %%
def count_backtrack(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return backtrack(T, S, 0, "")
    return 0

# %% [markdown]
# Probando el algoritmo con distintos casos se obtiene como resultado:

# %%
print(count_backtrack('ACAC','ACACBCA'))
print(count_backtrack('ABAB','BABA'))
print(count_backtrack('ACABD','ACABDBCACA'))
print(count_backtrack('DBACA', 'ACABD'))
print(count_backtrack('AABBAA','BABAAA'))
print(count_backtrack('AABBAA','CHAABBAA'))
print(count_backtrack('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para el ejemplo donde $T$ (prefijo) es "ABAB" y la cadena $S$ es BABA se tiene:
# 1. B $\rightarrow$ BA $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
# 2. B $\rightarrow$ AB $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
#
# *Resultado*: 4

# %% [markdown]
# Se puede apreciar que, aunque el algoritmo resuelve el problema presenta una gran complejidad temporal, la ventaja radica en que para próximos algoritmos que tengan menor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto. Se conoce que $|T| = m$ y $|S| = n$, por tanto:
#
# \begin{equation*}
#     T(n,m) = 2 T(n-1) + 1
# \end{equation*}
#
# donde por Teorema Maestro pertence a $\theta(2^n)$

# %% [markdown]
# Se puede observar que la primera letra colocándola al principio o al final genera exactamente la misma ramificación, por lo que sería mejor evitar hacer esta segunda ramificación innecesariamente, para ello:

# %%
def count_backtrack_modified(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando este algoritmo obtenemos los mismmos resultados, con una ligera mejora en eficiencia:

# %%
print(count_backtrack_modified('ACAC','ACACBCA'))
print(count_backtrack_modified('ACAC','CACA'))
print(count_backtrack_modified('ACABD','ACABDBCACA'))
print(count_backtrack_modified('DBACA', 'ACABD'))
print(count_backtrack_modified('AABBAA','BABAAA'))
print(count_backtrack_modified('AABBAA','CHAABBAA'))
print(count_backtrack_modified('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Como propuesta para una mejor solución a lo anterior, se realizó un memoize ya que en algunos llamados se hacían cálculos sobre subcadenas que ya se habían realizado con anterioridad, por lo que sería mejor guardar por subsecuencias de la cadena formada $A$, la subcadena restante de $S$, así como la cantidad de subsecuencias de operaciones posibles realizadas.

# %%
def count_backtrack_memoize(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        memoize = {}
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            dict_str = S[index+1:len(S)]
            word_form = char + A
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant = memoize[dict_str][word_form]
            else: 
                cant = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant}
            word_form = A + char
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant += memoize[dict_str][word_form]
            else:
                cant2 = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant2}
                cant += cant2
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_backtrack_memoize('ACAC','ACACBCA'))
print(count_backtrack_memoize('ABAB','BABA'))
print(count_backtrack_memoize('ACABD','ACABDBCACA'))
print(count_backtrack_memoize('DBACA', 'ACABD'))
print(count_backtrack_memoize('AABBAA','BABAAA'))
print(count_backtrack_memoize('AABBAA','CHAABBAA'))
print(count_backtrack_memoize('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Aunque este algoritmo constituye una mejora significativa, sigue presentando una complejidad temporal excesiva, ya que en el peor de los casos no se repiten patrones (subcadenas) y por tanto sigue perteneciendo a $O(2^n)$ con una complejidad espacial superior. La ventaja radica en que para próximos algoritmos que tengan mejor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto.

# %% [markdown]
# Fue necesario encontrar otras vías para solucionar el ejercicio. Partiremos de los posibles casos en que puede aparecer la cadena $T$ (el prefijo), en la cadena creada (genéticamente modificada) $A$.
#
# Si se comienza a leer la cadena que se desea modificar desde atrás hacia adelante se puede observar que:
# + El último elemento podría ser colocado hacia adelante si dicho caracter es igual al primer elemento del prefijo dado que luego de él no se va a poder colocar ningún otro elemento en la cadena.
#     + A partir de este momento, el problema se reduce a calcular la cantidad de secuencias de operaciones en la que se puede formar un genoma modificado desde el inicio de la cadena hasta el caracter anterior a este elemento y el prefijo desde el segundo elemento hasta el final:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1} p_1)$ $\rightarrow$ $method(p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + El último elemento igualmente siempre se puede poner detrás
#     + Si no pertence al prefijo, el problema se reduce a generar una secuencia de operaciones tal que se obtenga una cadena a partir del resto de esta (sin dicho elemento) teniendo en cuenta todo el prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... a_j)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + De igual forma este caracter se puede considerar poner detrás, pero si pertence al prefijo entonces debe ser el último elemento del mismo ya que es el último que se coloca, siendo el tamaño del prefijo igual al de la cadena
#     + Este problema se reduce a generar con el resto de la cadena el resto del prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... p_i)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_{i-1}~~~~y~~~~a_1 a_2 ... a_{j-1})$

# %%
def count_naive_recursive(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def naive_recursive(S,T):
            if len(S) < len(T): return 0
            if len(S)==1: 
                if len(T)==1 and T[0]==S[0]: return 2
                return 0
            if len(T)==0 : return 0
            output = naive_recursive(S[0:len(S)-1],T)
            if S[-1]==T[0]: 
                if len(T)==1: output += 2**(len(S)-1)
                else: output += naive_recursive(S[0:len(S)-1],T[1:])
            if len(S)==len(T) and S[-1]==T[-1]: output += naive_recursive(S[0:len(S)-1],T[0:len(T)-1])
            return output
        return naive_recursive(S,T)
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_naive_recursive('ACAC','ACACBCA'))
print(count_naive_recursive('ABAB','BABA'))
print(count_naive_recursive('ACABD','ACABDBCACA'))
print(count_naive_recursive('DBACA', 'ACABD'))
print(count_naive_recursive('AABBAA','BABAAA'))
print(count_naive_recursive('AABBAA','CHAABBAA'))
print(count_naive_recursive('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para este algoritmo se hizo uso de dp guardando los resultados de los cálculos anteriores siguiendo el flujo del algoritmo anterior con sus 3 índices.
# Por lo que este algoritmo pertenece a $O(m^2*n)$

# %%
def count_dynamic(T:str, S:str):
    if len(T) > len(S): return 0
    dp=[ [ [0 for i in range(len(S))] for i in range(len(T))] for i in range(len(T)) ]
    i=len(T)-1
    while i>=0:
        for j in range(i,len(T)):
            for k in range(len(S)):
                m=j-i
                if m > k:
                    dp[i][j][k]=0
                    continue
                if k==0:
                    if S[0] == T[i]: dp[i][j][k]=2
                    else: dp[i][j][k]=0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
                    continue
                if k >0 : dp[i][j][k]=dp[i][j][k-1]
                if S[k] == T[i]:
                    if m==0: dp[i][j][k]+=2**k
                    elif i<len(T)-1 and k>0: dp[i][j][k]+=dp[i+1][j][k-1]
                if k==m and S[k] == T[j] and j>0 and k>0: dp[i][j][k]+=dp[i][j-1][k-1]
        i-=1
    return dp[0][len(T)-1][len(S)-1]

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_dynamic('ACAC','ACACBCA'))
print(count_dynamic('ABAB','BABA'))
print(count_dynamic('ACABD','ACABDBCACA'))
print(count_dynamic('DBACA', 'ACABD'))
print(count_dynamic('AABBAA','BABAAA'))
print(count_dynamic('AABBAA','CHAABBAA'))
print(count_dynamic('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Explicaciones del nuevo algoritmo!!!

# %%
def count_first_memoize(T,S):
    dp=[[[-1 for i in range(len(S))] for i in range(len(T))]for i in range(len(T))]
    return count_memoize(0,len(T)-1,len(S)-1,T,S,dp)

def count_memoize(p:int, q:int, k:int,T:str,S:str,dp):
    if dp[p][q][k]>=0: return dp[p][q][k]
    count = 0
    m=q-p+1
    for i, elem in enumerate(S[0:k+1]):
        if elem == T[p]:
            if m == 1:
                if i == 0: count+=2
                else: count += 2**i
            elif i > 0 and i >= m-1: count += count_memoize(p+1,q,i-1,T,S,dp)
            elif i > 0 and i < m-1 and T[p+i+1:q+1] == S[i+1:m]: count += count_memoize(p+1,p+i,i-1,T,S,dp)
            elif i == 0 and T[p+1:q+1] == S[1:m]: count += 2
    dp[p][q][k]=count
    return count

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_first_memoize('ACAC','ACACBCA'))
print(count_first_memoize('ACAC','CACA'))
print(count_first_memoize('ACABD','ACABDBCACA'))
print(count_first_memoize('DBACA', 'ACABD'))
print(count_first_memoize('AABBAA','BABAAA'))
print(count_first_memoize('AABBAA','CHAABBAA'))
print(count_first_memoize('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# En las siguientes líneas de código se realizó un generador de cadenas que juegan el rol de prefijo (cocodrilo) y genoma a modificar (gallina) haciendo particiones en el prefijo, insertando un caracter random en alguna partición e invirtiendo la secuencia. Se comprueban los resultados entre los algoritmos.

# %%
import random
VOC = ["C","T","G","A","U","R","D"]

def generate_prefix(a=10,b=15):
    length = random.randint(a, b)
    prefix = ""
    while length > 0:
        letter = random.randint(0, len(VOC)-1)
        pos = random.randint(0,1)
        if pos:
            prefix += VOC[letter]
        else:
            prefix = VOC[letter] + prefix
        length-=1
    return prefix

def generate_secuence(prefix:str):
    secuence = ""
    while len(secuence) < 40:
        letter = random.randint(0, len(VOC)-1)
        partition = list(prefix.partition(random.choice(prefix)))
        pos = random.randint(0,len(partition))
        partition.insert(pos, VOC[letter])
        secuence += "".join(reversed(partition))
        secuence
    return secuence
   
TEST = 1
while TEST <= 100:
    print(f'TEST NO. {TEST}')
    prefix = generate_prefix()
    secuence = generate_secuence(prefix)
    print(f'PREFIX: {prefix} \nSECUENCE: {secuence}')
    #c_back = count_backtrack_memoize(prefix,secuence)
    #print(f'Naive Recursive: {c_back}')
    c_naive = count_naive_recursive(prefix,secuence)
    print(f'Naive Recursive: {c_naive}')
    c_dyn = count_dynamic(prefix,secuence)
    print(f'Naive Recursive: {c_dyn}')
    c_fm = count_first_memoize(prefix,secuence)
    print(f'First Memoize: {c_fm}')
    print()
    ##assert c_back == c_naive == c_dyn
    assert c_naive == c_dyn == c_fm
    TEST+=1
# Out:
# TEST NO. 1
# PREFIX: TDUARTRDURGT
# SECUENCE: UARTRDURGTUDTARTRDURGTUGTDUARTRDURGTDTTTRDURGTRRTDUA
# Naive Recursive: 80
# Naive Recursive: 80
# First Memoize: 80
#
# TEST NO. 2
# PREFIX: CGRCATUGTDARGGA
# SECUENCE: CATUGTDARGGARCGCARGGADDCGRCATUGTRCATUGTDARGGAGRC
# Naive Recursive: 104
# Naive Recursive: 104
# First Memoize: 104
#
# TEST NO. 3
# PREFIX: DAATTDTCTGU
# SECUENCE: CUDAATTDTCTGAATTDTCTGUDDAATTDTCTGUDARUDAATTDTCTG
# Naive Recursive: 270
# Naive Recursive: 270
# First Memoize: 270
#
# TEST NO. 4
# PREFIX: RTACCGAGCDTAA
# SECUENCE: CCCGAGCDTAAARTCCGAGCDTAAADRTACCGAGCDTAATRR
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 5
# PREFIX: CTTTUDRGCAR
# SECUENCE: GCARRCTTTUDGGCARRTCTTTUDTTUDRGCARUTCGCARURCTTTUD
# Naive Recursive: 12
# Naive Recursive: 12
# First Memoize: 12
#
# TEST NO. 6
# PREFIX: GTADCADGAGUUR
# SECUENCE: RAGTADCADGAGUUGTADCADGAGUURGURTUGTADCADGAG
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 7
# PREFIX: DACURDGTDDDCC
# SECUENCE: ACURDGTDDDCCDTACURDGTDDDCCDRDDDCCTDACURDGC
# Naive Recursive: 22
# Naive Recursive: 22
# First Memoize: 22
#
# TEST NO. 8
# PREFIX: GRARTUAUAAUC
# SECUENCE: RRTUAUAAUCAGRARTUAUAAUCCRGRTUAUAAUCAGGRAUAAUCUGRARTG
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 9
# PREFIX: DTRACCDDTUGR
# SECUENCE: RGUDTRACCDDTUACCDDTUGRRRDTDACCDDTUGRRDTACCDDTUGRRRDT
# Naive Recursive: 16
# Naive Recursive: 16
# First Memoize: 16
#
# TEST NO. 10
# PREFIX: DUTCRCDGAUAUUDU
# SECUENCE: GTCRCDGAUAUUDUUDRCDGAUAUUDUCCDUTAUAUUDUDGDUTCRCD
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 11
# PREFIX: CUDTTGAURDR
# SECUENCE: TTGAURDRDCUCDTTGAURDRUUCTGAURDRTCUDTTGAURDRTCUDU
# Naive Recursive: 172
# Naive Recursive: 172
# First Memoize: 172
#
# TEST NO. 12
# PREFIX: AUCAUGCRUGDDR
# SECUENCE: DRDDAUCAUGCRUGDRDCAUCAUGCRUGGCRUGDDRGAUCAU
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 13
# PREFIX: CTRGDACCGGAR
# SECUENCE: DACCGGARGCTRTTGDACCGGARRCTUDACCGGARGCTRGDACCGGARRCTT
# Naive Recursive: 234
# Naive Recursive: 234
# First Memoize: 234
#
# TEST NO. 14
# PREFIX: UTCUGCRRUTUTTC
# SECUENCE: CUGCRRUTUTTCTRUGCUGCRRUTUTTCTURUGCRRUTUTTCCUT
# Naive Recursive: 68
# Naive Recursive: 68
# First Memoize: 68
#
# TEST NO. 15
# PREFIX: RCGAAUUGGDTRCR
# SECUENCE: RCRDTRCGAAUUGGDCCGAAUUGGDTRCRRTRCRDRCGAAUUGGD
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 16
# PREFIX: AUGTAUATDURUC
# SECUENCE: GTAUATDURUCUAAGTAUATDURUCUGAAUATDURUCTGAUG
# Naive Recursive: 58
# Naive Recursive: 58
# First Memoize: 58
#
# TEST NO. 17
# PREFIX: DGUTTRATTC
# SECUENCE: DTTRATTCUDGUTRATTCTDGUTRATTCTDGUATTRATTCCUDG
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 18
# PREFIX: ADCCGGCUUG
# SECUENCE: DCGGCUUGCADCCGGCUUGTDACGGCUUGCCADUCGGCUUGCAD
# Naive Recursive: 125752
# Naive Recursive: 125752
# First Memoize: 125752
#
# TEST NO. 19
# PREFIX: TCRATTUTCCU
# SECUENCE: TCCUUTCRATTCRATTUTCCUCRTATTUTCCURGTCATTUTCCUGRTC
# Naive Recursive: 1068
# Naive Recursive: 1068
# First Memoize: 1068
#
# TEST NO. 20
# PREFIX: RUGRRUDGARAUGA
# SECUENCE: TRAUGAARUGRRUDGRRUDGARAUGADGRUUGRRUDGARAUGAUR
# Naive Recursive: 3120
# Naive Recursive: 3120
# First Memoize: 3120
#
# TEST NO. 21
# PREFIX: RTATTDRGDGURUU
# SECUENCE: CTATTDRGDGURUURDGURUUGDRTATTDRTATTDRGDGURUURC
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 22
# PREFIX: RCTACUDRGCRGCD
# SECUENCE: CTACUDRGCRGCDRCDRGCRGCDUGRCTACCRGCDGARCTACUDR
# Naive Recursive: 174
# Naive Recursive: 174
# First Memoize: 174
#
# TEST NO. 23
# PREFIX: ATTGATRRUCU
# SECUENCE: ATRRUCUTGATTRUCURATTGATRCUTUATTGATRRRUCUTRATTGAT
# Naive Recursive: 59460
# Naive Recursive: 59460
# First Memoize: 59460
#
# TEST NO. 24
# PREFIX: GDACGGGACTAG
# SECUENCE: DDACGGGACTAGGDACGGGACTAGGUDACGGGACTAGGGDACGGGACTAGDG
# Naive Recursive: 32231984
# Naive Recursive: 32231984
# First Memoize: 32231984
#
# TEST NO. 25
# PREFIX: UCGDGTTARTTGRA
# SECUENCE: GDGTTARTTGRACAUDRTTGRAAUCGDGTTGDGTTARTTGRAGUC
# Naive Recursive: 16
# Naive Recursive: 16
# First Memoize: 16
#
# TEST NO. 26
# PREFIX: CGGADRRDUTDRDA
# SECUENCE: GRRDUTDRDADCGGADRDATCGGADRRDUURRDUTDRDADCCGGA
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 27
# PREFIX: ADCDCTGARDRR
# SECUENCE: GARDRRATADCDCDCDCTGARDRRATDRRRADCDCTGAADCTGARDRRCCAD
# Naive Recursive: 982
# Naive Recursive: 982
# First Memoize: 982
#
# TEST NO. 28
# PREFIX: AGGTRUCCGRRUDRC
# SECUENCE: CGRRUDRCCAGGTRUACGRRUDRCCAGGTRUUGUCCGRRUDRCRAGGT
# Naive Recursive: 18
# Naive Recursive: 18
# First Memoize: 18
#
# TEST NO. 29
# PREFIX: CGCUDTATGAT
# SECUENCE: GCUDTATGATTCDTATGATUCGCGTGATACGCUDTGGATGATTCGCUD
# Naive Recursive: 14
# Naive Recursive: 14
# First Memoize: 14
#
# TEST NO. 30
# PREFIX: TRRRARUDCCGGGT
# SECUENCE: CRRRARUDCCGGGTTCGGTGTRRRARUDCCTGGTGTRRRARUDCC
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 31
# PREFIX: AGUGRCUARCRATCR
# SECUENCE: UARCRATCRCTAGUGRCUARCRATCRRAGUGDUARCRATCRCTAGUGR
# Naive Recursive: 84
# Naive Recursive: 84
# First Memoize: 84
#
# TEST NO. 32
# PREFIX: AUTUUTACGDDGDT
# SECUENCE: DDGDTDAUTUUTACGUUTACGDDGDTGTAUDDGDTGAUTUUTACA
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 33
# PREFIX: RGRDCGDTACAG
# SECUENCE: GDTACAGCCRGRDCAGARRGRDCGDTCCAGARGRDCGDTCRDCGDTACAGGR
# Naive Recursive: 598
# Naive Recursive: 598
# First Memoize: 598
#
# TEST NO. 34
# PREFIX: GTDUGGADGCDDC
# SECUENCE: UGGADGCDDCGDGTTUGGADGCDDCDGTDDCUCGTDUGGADG
# Naive Recursive: 114
# Naive Recursive: 114
# First Memoize: 114
#
# TEST NO. 35
# PREFIX: TRDUTDDTAUU
# SECUENCE: RDUTDDTAUUGTARDUTDDTAUUTRDUTDDTAUUTRDUTDDTAUUART
# Naive Recursive: 110628
# Naive Recursive: 110628
# First Memoize: 110628
#
# TEST NO. 36
# PREFIX: UDTTDDCUGCR
# SECUENCE: CRGUDTTDDCUDTTDDCUGCRRDUUGCRCUDTTDDRTTDDCUGCRTUD
# Naive Recursive: 1656
# Naive Recursive: 1656
# First Memoize: 1656
#
# TEST NO. 37
# PREFIX: RGDCCCTTTDDDCA
# SECUENCE: TGDCCCTTTDDDCARCCCTTTDDDCADDRGCCCTTTDDDCADCRG
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 38
# PREFIX: DRGTTUADRDA
# SECUENCE: TUADRDATDRGDDRDARADRGTTUGTUADRDATDRGTUADRDARTDRG
# Naive Recursive: 2954
# Naive Recursive: 2954
# First Memoize: 2954
#
# TEST NO. 39
# PREFIX: GRACRTGUATTURR
# SECUENCE: CRTGUATTURRADGRACRTGUATTURRRGRRACRTGUATTURRRG
# Naive Recursive: 148
# Naive Recursive: 148
# First Memoize: 148
#
# TEST NO. 40
# PREFIX: CUTUUADATGD
# SECUENCE: TUUADATGDUCATUUADATGDGUCTUUADATGDURCUUADATGDTCUT
# Naive Recursive: 234
# Naive Recursive: 234
# First Memoize: 234
#
# TEST NO. 41
# PREFIX: ARARCARCGDAARR
# SECUENCE: RARCARCGDAARRDAARCARCGDAARRRAAUARCARCGDAARRRA
# Naive Recursive: 48
# Naive Recursive: 48
# First Memoize: 48
#
# TEST NO. 42
# PREFIX: URAGUTARDUG
# SECUENCE: ARAGUTARDUGUUGADURAGUTARGAGUTARDUGRURAGUTARDUGUG
# Naive Recursive: 96048
# Naive Recursive: 96048
# First Memoize: 96048
#
# TEST NO. 43
# PREFIX: UUCUAGURCRAD
# SECUENCE: UCUAGURCRADUDCRADRRUUCUAGURUAGURCRADCUUUCUAGURCRADUA
# Naive Recursive: 92212
# Naive Recursive: 92212
# First Memoize: 92212
#
# TEST NO. 44
# PREFIX: GCRGRRTAURAUGAA
# SECUENCE: RAUGAARUGCRGRRTARRGRRTAURAUGAACGURAUGAAAGCRGRRTA
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 45
# PREFIX: TUCRRDARUCGAT
# SECUENCE: CRRDARUCGATRUTTCRRDARUCGATUTTCRRDARUCGATUT
# Naive Recursive: 38
# Naive Recursive: 38
# First Memoize: 38
#
# TEST NO. 46
# PREFIX: GGRRADUUCDGD
# SECUENCE: UUCDGDADGGRRAUCDGDUGGGRRADAUUCDGDDGGRRAGRRADUUCDGDAG
# Naive Recursive: 1192
# Naive Recursive: 1192
# First Memoize: 1192
#
# TEST NO. 47
# PREFIX: GACCTURRGCCRTC
# SECUENCE: RGCCRTCRTGACCTUCTURRGCCRTCTCGARGCCRTCRGACCTUG
# Naive Recursive: 154
# Naive Recursive: 154
# First Memoize: 154
#
# TEST NO. 48
# PREFIX: RUCTCGRUURGAUA
# SECUENCE: CCTCGRUURGAUAURUCTCGRUURGAUARUCTCGRUURGAUACUR
# Naive Recursive: 7168
# Naive Recursive: 7168
# First Memoize: 7168
#
# TEST NO. 49
# PREFIX: GRDATTDGRCG
# SECUENCE: DATTDGRCGRTGATTDGRCGUDGRUDATTDGRCGRGDATTDGRCGRRG
# Naive Recursive: 1482
# Naive Recursive: 1482
# First Memoize: 1482
#
# TEST NO. 50
# PREFIX: ARCGRACRDD
# SECUENCE: GRACRDDCTARUDDARCGRACRDDDARCGRACRURCGRACRDDA
# Naive Recursive: 34002458
# Naive Recursive: 34002458
# First Memoize: 34002458
#
# TEST NO. 51
# PREFIX: ATRUDUGAATAA
# SECUENCE: TRUDUGAATAAARTRUDUGAATAAUADUGAATAAUATRURRUDUGAATAATA
# Naive Recursive: 6180
# Naive Recursive: 6180
# First Memoize: 6180
#
# TEST NO. 52
# PREFIX: GDAAATGRUAGDC
# SECUENCE: UUAGDCRGDAAATGAAATGRUAGDCCDGADAAATGRUAGDCG
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 53
# PREFIX: CCRCARRDCD
# SECUENCE: CDTDCCRCARRRRDCDAACCRCRCARRDCDRCCCRCARRDCDUC
# Naive Recursive: 325036
# Naive Recursive: 325036
# First Memoize: 325036
#
# TEST NO. 54
# PREFIX: UAUATTCGADRCAU
# SECUENCE: GADRCAUTCUAUATTCAURGUAUATTCGADGADRCAUCUUAUATT
# Naive Recursive: 300
# Naive Recursive: 300
# First Memoize: 300
#
# TEST NO. 55
# PREFIX: UDGUGGAGCDT
# SECUENCE: UGGAGCDTGUDAGUGGAGCDTDUUGUGGAGCDTGUDTUDGUGGAGCDU
# Naive Recursive: 6884
# Naive Recursive: 6884
# First Memoize: 6884
#
# TEST NO. 56
# PREFIX: CUADCTRCRRA
# SECUENCE: GCRRARCUADCTDCTRCRRAACUTCRRARRCUADCTUADCTRCRRARC
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 57
# PREFIX: UGGRAAAATRGGTR
# SECUENCE: AAATRGGTRDAUGGRRRGGTRTUGGRAAAAAAATRGGTRAUGGRT
# Naive Recursive: 7224
# Naive Recursive: 7224
# First Memoize: 7224
#
# TEST NO. 58
# PREFIX: DUUCCCUCCAU
# SECUENCE: UADUUCCCUCCAUCCCUCCAUUDDUCCCUCCAUUDDUCCCUCCAUUAD
# Naive Recursive: 42017210
# Naive Recursive: 42017210
# First Memoize: 42017210
#
# TEST NO. 59
# PREFIX: CACACCTTCTG
# SECUENCE: ACACCTTCTGCUAGCACACCTTCTACACCTTCTGCRTGCACACCTTCT
# Naive Recursive: 1801792
# Naive Recursive: 1801792
# First Memoize: 1801792
#
# TEST NO. 60
# PREFIX: GAGDRDGDRDAGCTC
# SECUENCE: RDGDRDAGCTCDUGAGCAGDRDGDRDAGCTCGDAGDRDGDRDAGCTCG
# Naive Recursive: 77540
# Naive Recursive: 77540
# First Memoize: 77540
#
# TEST NO. 61
# PREFIX: UATRAGGTTAURDGG
# SECUENCE: GGDRUATRAGGTTAURGTTAURDGGRGUATRARAGGTTAURDGGTGUA
# Naive Recursive: 3024
# Naive Recursive: 3024
# First Memoize: 3024
#
# TEST NO. 62
# PREFIX: RTTCRGRATTCUT
# SECUENCE: DTCRGRATTCUTTRTCRGRATTCUTTURTCRGRATTCUTTRU
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 63
# PREFIX: ADADCACGURR
# SECUENCE: ACGURRCADADCDADCACGURRAURRCADADCACGUTACGURRCADAD
# Naive Recursive: 782
# Naive Recursive: 782
# First Memoize: 782
#
# TEST NO. 64
# PREFIX: DUGDCATATTTD
# SECUENCE: UGDCATATTTDDATATTTDADUGDCUATTTDTDUGDCATUGDCATATTTDDC
# Naive Recursive: 1222
# Naive Recursive: 1222
# First Memoize: 1222
#
# TEST NO. 65
# PREFIX: GCATCRGGCRT
# SECUENCE: TCRGGCRTAGCUCRGGCRTTCGCAGGCRTRRGCATCCRGGCRTTGCAG
# Naive Recursive: 650
# Naive Recursive: 650
# First Memoize: 650
#
# TEST NO. 66
# PREFIX: RDTDGGRUARCT
# SECUENCE: DTDGGRUARCTRRTDGGRUARCTCDRDTDGGRUARCTDRARCTUARDTDGGR
# Naive Recursive: 44
# Naive Recursive: 44
# First Memoize: 44
#
# TEST NO. 67
# PREFIX: ACCUDTUURTATRDD
# SECUENCE: UURTATRDDTACCUDGTATRDDRACCUDTUUUTUURTATRDDDRACCU
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 68
# PREFIX: GCADUDADDG
# SECUENCE: ADUDADDGCUGRDUDADDGAGCRUDADDGDGCAUDADDGRDGCA
# Naive Recursive: 4660
# Naive Recursive: 4660
# First Memoize: 4660
#
# TEST NO. 69
# PREFIX: UCURAAAAUT
# SECUENCE: CURAAAAUTURUCURAAAAUTUCURAAAAUTDUCURAAAAUTUU
# Naive Recursive: 6168
# Naive Recursive: 6168
# First Memoize: 6168
#
# TEST NO. 70
# PREFIX: UDRGGCCTGGRR
# SECUENCE: RRGGCCTGGRRDUGCCTGGRRGCUDRDGGCCTGGRRRUDRGCCTGGRRGUDR
# Naive Recursive: 916
# Naive Recursive: 916
# First Memoize: 916
#
# TEST NO. 71
# PREFIX: RGGAUADTCGCR
# SECUENCE: GAUADTCGCRUGRGAUADTCGCRGCRGAUADTCGCRUGRTCGCRTRGGAUAD
# Naive Recursive: 74
# Naive Recursive: 74
# First Memoize: 74
#
# TEST NO. 72
# PREFIX: UGUDTDRRCR
# SECUENCE: RCRRUUGUDTDGUDTDRRCRTUDRRCRTUGUDGTDRRCRUDUGU
# Naive Recursive: 3541596
# Naive Recursive: 3541596
# First Memoize: 3541596
#
# TEST NO. 73
# PREFIX: UUUTTTDTUA
# SECUENCE: TTDTUATUUUURUUTTTDTUAUTTTDTUATUUUUTTDTUATUUU
# Naive Recursive: 158344772
# Naive Recursive: 158344772
# First Memoize: 158344772
#
# TEST NO. 74
# PREFIX: GRDDTDAGUTTDC
# SECUENCE: DTDAGUTTDCTDGRDCGRDDTDAGUTTDDTDAGUTTDCDDGR
# Naive Recursive: 40
# Naive Recursive: 40
# First Memoize: 40
#
# TEST NO. 75
# PREFIX: DRGTTUTCDACTRGA
# SECUENCE: UTTUTCDACTRGAGDRTRGTTUTCDACTRGADCTTUTCDACTRGAGDR
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 76
# PREFIX: RAADRRAUCDUDC
# SECUENCE: TCDUDCURAADRRAAADRRAUCDUDCRTAADRRAUCDUDCDR
# Naive Recursive: 348
# Naive Recursive: 348
# First Memoize: 348
#
# TEST NO. 77
# PREFIX: TAAADDACTCDCUR
# SECUENCE: DACTCDCURTDTAAAARTAAADDACTCDCUAAADDACTCDCURCT
# Naive Recursive: 1096
# Naive Recursive: 1096
# First Memoize: 1096
#
# TEST NO. 78
# PREFIX: UUCCUUAUUUAU
# SECUENCE: DUCCUUAUUUAUUDCUUAUUUAUCUUDUUUAUAUUCCUUCUUAUUUAURCUU
# Naive Recursive: 24708217798
# Naive Recursive: 24708217798
# First Memoize: 24708217798
#
# TEST NO. 79
# PREFIX: CATGRUUGATAG
# SECUENCE: UGATAGUUCATGRRTGRUUGATAGACURUUGATAGGCATRUUGATAGGCATU
# Naive Recursive: 1680010
# Naive Recursive: 1680010
# First Memoize: 1680010
#
# TEST NO. 80
# PREFIX: RRGUTCCTDAC
# SECUENCE: CTDACCRRGUTRCTDACCRRGUTDACDRRGUTCCTATCCTDACUTRRG
# Naive Recursive: 10
# Naive Recursive: 10
# First Memoize: 10
#
# TEST NO. 81
# PREFIX: AURRCCGDUDDADD
# SECUENCE: RCCGDUDDADDARAUCGDUDDADDCAURRUUURRCCGDUDDADDA
# Naive Recursive: 76
# Naive Recursive: 76
# First Memoize: 76
#
# TEST NO. 82
# PREFIX: TUAGRRARUU
# SECUENCE: AAGRRARUUUTAGRRARUUUATRARUURRTUAGRARUURTUAGD
# Naive Recursive: 3213056
# Naive Recursive: 3213056
# First Memoize: 3213056
#
# TEST NO. 83
# PREFIX: GUDUAUCGUA
# SECUENCE: RDUAUCGUAUGUDUAUCGUAGRDUAUCGUAAUGDDUAUCGUAUG
# Naive Recursive: 1306560
# Naive Recursive: 1306560
# First Memoize: 1306560
#
# TEST NO. 84
# PREFIX: DADRADAGDCUT
# SECUENCE: ADRADAGDCUTDCGTDADRADAGDCUADRADAGDCUTDRUTCDADRADAGDA
# Naive Recursive: 52
# Naive Recursive: 52
# First Memoize: 52
#
# TEST NO. 85
# PREFIX: CUARUADRTU
# SECUENCE: RTUGDCUARUAUADRTURUCUARRUADRTUACUARUADRTUUUC
# Naive Recursive: 25680
# Naive Recursive: 25680
# First Memoize: 25680
#
# TEST NO. 86
# PREFIX: UTDRRTCCUCD
# SECUENCE: DDRRTCCUCDTUCUCDCCUTDRRTDRRTCCUCDTUGCUCDCDUTDRRT
# Naive Recursive: 48608
# Naive Recursive: 48608
# First Memoize: 48608
#
# TEST NO. 87
# PREFIX: DUUGCGURCATR
# SECUENCE: RTTDUUGCGURCAUGCGURCATRUGDRTDDUUGCGURCACATRRDUUGCGUR
# Naive Recursive: 0
# Naive Recursive: 0
# First Memoize: 0
#
# TEST NO. 88
# PREFIX: GDDAGATURDCAR
# SECUENCE: DDAGATURDCARGCDAGATURDCARDRGGATURDCARGAGDD
# Naive Recursive: 24
# Naive Recursive: 24
# First Memoize: 24
#
# TEST NO. 89
# PREFIX: AAUDAACCTUUCU
# SECUENCE: AACCTUUCUDCAAUUUCUUTAAUDAACCTCTUUCUCAAUDAA
# Naive Recursive: 772
# Naive Recursive: 772
# First Memoize: 772
#
# TEST NO. 90
# PREFIX: RAUCUDRUDGDAU
# SECUENCE: CUDRUDGDAUUCRARUDGDAUGDRAUCUUCUDRUDGDAUGAR
# Naive Recursive: 88
# Naive Recursive: 88
# First Memoize: 88
#
# TEST NO. 91
# PREFIX: AGRUAAGUCT
# SECUENCE: GRUAAGUCTATTTAGRUAAGUCCAAGUCTUAGRGRUAAGUCTUA
# Naive Recursive: 20
# Naive Recursive: 20
# First Memoize: 20
#
# TEST NO. 92
# PREFIX: AAADTCDDAGTD
# SECUENCE: CDDAGTDUTAAADTCDDAGTDDCAAACDDAGTDTAAADCTCDDAGTDDDAAA
# Naive Recursive: 1375476
# Naive Recursive: 1375476
# First Memoize: 1375476
#
# TEST NO. 93
# PREFIX: CADGRRUGDACDD
# SECUENCE: ADGRRUGDACDDCRADGRRUGDACDDDCGRRUGDACDDDRCA
# Naive Recursive: 2586
# Naive Recursive: 2586
# First Memoize: 2586
#
# TEST NO. 94
# PREFIX: TGTTRGTTCDRGCCG
# SECUENCE: TDRGCCGCTGTTRGTTGTTCDRGCCGURTGTTDGTTRGTTCDRGCCGT
# Naive Recursive: 384
# Naive Recursive: 384
# First Memoize: 384
#
# TEST NO. 95
# PREFIX: GDAAAUARUTRC
# SECUENCE: AAAUARUTRCUDGAAUARUTRCAUGDDAAAUARUTRCGCDCGDAAAUARUTR
# Naive Recursive: 72
# Naive Recursive: 72
# First Memoize: 72
#
# TEST NO. 96
# PREFIX: CUCTGUCTRR
# SECUENCE: AUCTGUCTRRCGUCTRRTRCUCUCTGUCTRRACUUCTGUCTRRC
# Naive Recursive: 1044480
# Naive Recursive: 1044480
# First Memoize: 1044480
#
# TEST NO. 97
# PREFIX: DGGDURDGUA
# SECUENCE: ADGGDURDGUGCGGDURDGUADGDURDGUAGTDTGGDURDGUAD
# Naive Recursive: 2088
# Naive Recursive: 2088
# First Memoize: 2088
#
# TEST NO. 98
# PREFIX: AATRDTAATAACTUT
# SECUENCE: ATRDTAATAACTUTTATAATAACTUTDAATRGRDTAATAACTUTGTAA
# Naive Recursive: 26
# Naive Recursive: 26
# First Memoize: 26
#
# TEST NO. 99
# PREFIX: ACAADUUUCGCUR
# SECUENCE: CAADUUUCGCURGAUUCGCURUACAADDAADUUUCGCURCAA
# Naive Recursive: 16
# Naive Recursive: 16
# First Memoize: 16
#
# TEST NO. 100
# PREFIX: AGRTCUDRUTDTTGU
# SECUENCE: GRTCUDRUTDTTGUAATCUDRUTDTTGURAGURTCUDRUTDTTGUGAC
# Naive Recursive: 8
# Naive Recursive: 8
# First Memoize: 8
