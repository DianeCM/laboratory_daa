# %% [markdown]
# # El Lab (DAA Project)
#
# En un laboratorio de la BIOFAM quieren modificar genéticamente una gallina para que sea más resistente a las enfermedades. Para esto deben de cambiar la secuencia de aminoácidos presentes en su genoma. La secuencia que quieren reproducir es la de los cocodrilos, que se sabe que son animales que han existido por millones de años. Entonces, dado que una secuencia de aminoácidos se puede codificar como una secuencia de caracteres se tiene:
#
# - $T$ es la secuencia de aminoácidos de los cocodrilos (tamaño $m$)
# - $S$ es la secuencia de aminoácidos de la gallina original (tamaño $n$)
# - $A$ es la secuencia de aminoácidos de la galllina a crear (inicialmente vacía)
#
# Para lograr que la gallina modificada adquiera la resistencia de un cocodrilo se sabe que su secuencia de aminoácidos $A$, debe contener como prefijo a $T$. Como en la BIOFAM hubo recortes de presupuesto solo cuentan con una máquina que puede hacer dos modificaciones genéticas:
# 1. Extrae y elimina el primer aminoácido de $S$ y lo coloca al principio de $A$
# 2. Extrae y elimina el primer aminoácido de $S$ y lo coloca al final de $A$
#
# Encuentre la **cantidad de secuencias de operaciones posibles** tales que la gallina genéticamente modificada sea resistente a las enfermedades.
#
# Aclaraciones del problema:
# + Se debe modificar la gallina ($A$) con todos los caracteres de $S$, no basta con solo tener el prefijo, se debe llegar al final.

# %% [markdown]
# ## Soluciones
# Para una primera solución se realizó un algoritmo en el que se hace un backtrack por cada una de las operaciones posibles para crear la cadena $A$ comprobando finalmente si contiene a la cadena $T$ como prefijo dando como resultado una secuencia posible de operaciones.

# %%
def count_backtrack(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return backtrack(T, S, 0, "")
    return 0

# %% [markdown]
# Probando el algoritmo con distintos casos se obtiene como resultado:

# %%
print(count_backtrack('ACAC','ACACBCA'))
print(count_backtrack('ABAB','BABA'))
print(count_backtrack('ACABD','ACABDBCACA'))
print(count_backtrack('DBACA', 'ACABD'))
print(count_backtrack('AABBAA','BABAAA'))
print(count_backtrack('AABBAA','CHAABBAA'))
print(count_backtrack('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para el ejemplo donde $T$ (prefijo) es "ABAB" y la cadena $S$ es BABA se tiene:
# 1. B $\rightarrow$ BA $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
# 2. B $\rightarrow$ AB $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
#
# *Resultado*: 4

# %% [markdown]
# Se puede apreciar que, aunque el algoritmo resuelve el problema presenta una gran complejidad temporal, la ventaja radica en que para próximos algoritmos que tengan menor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto. Se conoce que $|T| = m$ y $|S| = n$, por tanto:
#
# \begin{equation*}
#     T(n,m) = 2 T(n-1) + 1
# \end{equation*}
#
# donde por Teorema Maestro pertence a $\theta(2^n)$

# %% [markdown]
# Se puede observar que la primera letra colocándola al principio o al final genera exactamente la misma ramificación, por lo que sería mejor evitar hacer esta segunda ramificación innecesariamente, para ello:

# %%
def count_backtrack_modified(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando este algoritmo obtenemos los mismmos resultados, con una ligera mejora en eficiencia:

# %%
print(count_backtrack_modified('ACAC','ACACBCA'))
print(count_backtrack_modified('ACAC','CACA'))
print(count_backtrack_modified('ACABD','ACABDBCACA'))
print(count_backtrack_modified('DBACA', 'ACABD'))
print(count_backtrack_modified('AABBAA','BABAAA'))
print(count_backtrack_modified('AABBAA','CHAABBAA'))
print(count_backtrack_modified('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Como propuesta para una mejor solución a lo anterior, se realizó un memoize ya que en algunos llamados se hacían cálculos sobre subcadenas que ya se habían realizado con anterioridad, por lo que sería mejor guardar por subsecuencias de la cadena formada $A$, la subcadena restante de $S$, así como la cantidad de subsecuencias de operaciones posibles realizadas.

# %%
def count_backtrack_memoize(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        memoize = {}
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            dict_str = S[index+1:len(S)]
            word_form = char + A
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant = memoize[dict_str][word_form]
            else: 
                cant = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant}
            word_form = A + char
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant += memoize[dict_str][word_form]
            else:
                cant2 = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant2}
                cant += cant2
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_backtrack_memoize('ACAC','ACACBCA'))
print(count_backtrack_memoize('ABAB','BABA'))
print(count_backtrack_memoize('ACABD','ACABDBCACA'))
print(count_backtrack_memoize('DBACA', 'ACABD'))
print(count_backtrack_memoize('AABBAA','BABAAA'))
print(count_backtrack_memoize('AABBAA','CHAABBAA'))
print(count_backtrack_memoize('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Aunque este algoritmo constituye una mejora significativa, sigue presentando una complejidad temporal excesiva, ya que en el peor de los casos no se repiten patrones (subcadenas) y por tanto sigue perteneciendo a $O(2^n)$ con una complejidad espacial superior. La ventaja radica en que para próximos algoritmos que tengan mejor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto.

# %% [markdown]
# Fue necesario encontrar otras vías para solucionar el ejercicio. Partiremos de los posibles casos en que puede aparecer la cadena $T$ (el prefijo), en la cadena creada (genéticamente modificada) $A$.
#
# Si se comienza a leer la cadena que se desea modificar desde atrás hacia adelante se puede observar que:
# + El último elemento podría ser colocado hacia adelante si dicho caracter es igual al primer elemento del prefijo dado que luego de él no se va a poder colocar ningún otro elemento en la cadena.
#     + A partir de este momento, el problema se reduce a calcular la cantidad de secuencias de operaciones en la que se puede formar un genoma modificado desde el inicio de la cadena hasta el caracter anterior a este elemento y el prefijo desde el segundo elemento hasta el final:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1} p_1)$ $\rightarrow$ $method(p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + El último elemento igualmente siempre se puede poner detrás
#     + Si no pertence al prefijo, el problema se reduce a generar una secuencia de operaciones tal que se obtenga una cadena a partir del resto de esta (sin dicho elemento) teniendo en cuenta todo el prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... a_j)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + De igual forma este caracter se puede considerar poner detrás, pero si pertence al prefijo entonces debe ser el último elemento del mismo ya que es el último que se coloca, siendo el tamaño del prefijo igual al de la cadena
#     + Este problema se reduce a generar con el resto de la cadena el resto del prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... p_i)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_{i-1}~~~~y~~~~a_1 a_2 ... a_{j-1})$

# %%
def count_naive_recursive(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def naive_recursive(S,T):
            if len(S) < len(T): return 0
            if len(S)==1: 
                if len(T)==1 and T[0]==S[0]: return 2
                return 0
            if len(T)==0 : return 0
            output = naive_recursive(S[0:len(S)-1],T)
            if S[-1]==T[0]: 
                if len(T)==1: output += 2**(len(S)-1)
                else: output += naive_recursive(S[0:len(S)-1],T[1:])
            if len(S)==len(T) and S[-1]==T[-1]: output += naive_recursive(S[0:len(S)-1],T[0:len(T)-1])
            return output
        return naive_recursive(S,T)
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_naive_recursive('ACAC','ACACBCA'))
print(count_naive_recursive('ABAB','BABA'))
print(count_naive_recursive('ACABD','ACABDBCACA'))
print(count_naive_recursive('DBACA', 'ACABD'))
print(count_naive_recursive('AABBAA','BABAAA'))
print(count_naive_recursive('AABBAA','CHAABBAA'))
print(count_naive_recursive('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para este algoritmo se hizo uso de dp guardando los resultados de los cálculos anteriores siguiendo el flujo del algoritmo anterior con sus 3 índices.
# Por lo que este algoritmo pertenece a $O(n^2*m)$

# %%
def count_dynamic(T:str, S:str):
    if len(T) > len(S): return 0
    dp=[ [ [0 for i in range(len(S))] for i in range(len(T))] for i in range(len(T)) ]
    i=len(T)-1
    while i>=0:
        for j in range(i,len(T)):
            for k in range(len(S)):
                m=j-i
                if m > k:
                    dp[i][j][k]=0
                    continue
                if k==0:
                    if S[0] == T[i]: dp[i][j][k]=2
                    else: dp[i][j][k]=0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
                    continue
                if k >0 : dp[i][j][k]=dp[i][j][k-1]
                if S[k] == T[i]:
                    if m==0: dp[i][j][k]+=2**k
                    elif i<len(T)-1 and k>0: dp[i][j][k]+=dp[i+1][j][k-1]
                if k==m and S[k] == T[j] and j>0 and k>0: dp[i][j][k]+=dp[i][j-1][k-1]
        i-=1
    return dp[0][len(T)-1][len(S)-1]

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_dynamic('ACAC','ACACBCA'))
print(count_dynamic('ABAB','BABA'))
print(count_dynamic('ACABD','ACABDBCACA'))
print(count_dynamic('DBACA', 'ACABD'))
print(count_dynamic('AABBAA','BABAAA'))
print(count_dynamic('AABBAA','CHAABBAA'))
print(count_dynamic('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Explicaciones del nuevo algoritmo!!!

# %%
def solve_dp(T,S):
    n = len(S)
    m = len(T)
        
    if m > n:
        return 0
        
    dp = [[0 for j in range(n)] for i in range(n)]
    
    for i in range(n):
        if i >= m or T[i] == S[0]:
            dp[i][i] = 2
    
    for k in range(1, n):    
        c = S[k]
        
        i = 0        
        for j in range(k, n):
            if i >= m or c == T[i]:
                dp[i][j] += dp[i+1][j]
            if j >= m or c == T[j]:
                dp[i][j] += dp[i][j-1]            
            i += 1            
    dp
    return dp[0][-1]

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
# Probando el codigo

# %% [markdown]
# En las siguientes líneas de código se realizó un generador de cadenas que juegan el rol de prefijo (cocodrilo) y genoma a modificar (gallina) haciendo particiones en el prefijo, insertando un caracter random en alguna partición e invirtiendo la secuencia. Se comprueban los resultados entre los algoritmos.

# %%
import random
VOC = ["C","T","G","A","U","R","D"]

def generate_prefix(a=10,b=15):
    length = random.randint(a, b)
    prefix = ""
    while length > 0:
        letter = random.randint(0, len(VOC)-1)
        pos = random.randint(0,1)
        if pos:
            prefix += VOC[letter]
        else:
            prefix = VOC[letter] + prefix
        length-=1
    return prefix

def generate_secuence(prefix:str):
    secuence = ""
    while len(secuence) < 40:
        letter = random.randint(0, len(VOC)-1)
        partition = list(prefix.partition(random.choice(prefix)))
        pos = random.randint(0,len(partition))
        partition.insert(pos, VOC[letter])
        secuence += "".join(reversed(partition))
        secuence
    return secuence
   
TEST = 1
while TEST <= 100:
    print(f'TEST NO. {TEST}')
    prefix = generate_prefix()
    secuence = generate_secuence(prefix)
    print(f'PREFIX: {prefix} \nSECUENCE: {secuence}')
    #c_back = count_backtrack_memoize(prefix,secuence)
    #print(f'Naive Recursive: {c_back}')
    c_naive = count_naive_recursive(prefix,secuence)
    print(f'Naive Recursive: {c_naive}')
    c_dyn = count_dynamic(prefix,secuence)
    print(f'Naive Recursive: {c_dyn}')
    print()
    ##assert c_back == c_naive == c_dyn
    assert c_naive == c_dyn
    TEST+=1
# Out:
# TEST NO. 1
# PREFIX: TDUATUDCAUTAAURAAAUGRGATC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1279911994934082
# Solve DP:  -----> time: 0.2909712791442871
#
# TEST NO. 2
# PREFIX: CCTTATGUTGGRRDUATUTCARTTC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12099647521972656
# Solve DP:  -----> time: 0.22303414344787598
#
# TEST NO. 3
# PREFIX: DUTGGAAADAAGUDTDTATGCCCURRD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.136002779006958
# Solve DP:  -----> time: 0.21996355056762695
#
# TEST NO. 4
# PREFIX: TTUCUTCCGTTATRRUACUGRCACUG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1330404281616211
# Solve DP:  -----> time: 0.23662710189819336
#
# TEST NO. 5
# PREFIX: RARCADARARAATRGACAUTGAUTGUG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14323973655700684
# Solve DP:  -----> time: 0.22201251983642578
#
# TEST NO. 6
# PREFIX: GUTUTCDCARRGUURDTRUUTAUADUCRGACRG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.20647192001342773
# Solve DP:  -----> time: 0.22151780128479004
#
# TEST NO. 7
# PREFIX: DACURRRUDGRDGCTGDUCRACGACDCG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14774298667907715
# Solve DP:  -----> time: 0.2249131202697754
#
# TEST NO. 8
# PREFIX: GRTGGRTRUUCGCTDCAGAGTTAACD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1280834674835205
# Solve DP:  -----> time: 0.2195723056793213
#
# TEST NO. 9
# PREFIX: DRRRGTCRGARGCDGDGTCTTGTRRDCDRAG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.18693232536315918
# Solve DP:  -----> time: 0.22372961044311523
#
# TEST NO. 10
# PREFIX: CRCRTDCCTAUUUUTTDDCDGGARUCA
# SECUENCE: ...
# Dynamic Recursive: 15723595870453770566101167215372751081662454102772558502860795623305186310806802987603810034397451431951399816855398570989837175553763044977843417589966067540742292861623847750779358190107542545995147138832952716147963140923418202532139307700970170210 -----> time: 0.13607430458068848
# Solve DP: 15723595870453770566101167215372751081662454102772558502860795623305186310806802987603810034397451431951399816855398570989837175553763044977843417589966067540742292861623847750779358190107542545995147138832952716147963140923418202532139307700970170210 -----> time: 0.21852540969848633
#
# TEST NO. 11
# PREFIX: RCGTUCUTRGDCAUGTCUTRATUUTCUGGAGGUDR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.2293376922607422
# Solve DP:  -----> time: 0.21473431587219238
#
# TEST NO. 12
# PREFIX: RCCUDDCCRAUDUAAUDADCDGGUUDTRAUDR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1997067928314209
# Solve DP:  -----> time: 0.2244560718536377
#
# TEST NO. 13
# PREFIX: TDUGRATRDDGCTARRGCARTRDGRADDG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1646261215209961
# Solve DP:  -----> time: 0.2290503978729248
#
# TEST NO. 14
# PREFIX: DGATURRCDUTRRACTGADGUDUTGADDCG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.16888785362243652
# Solve DP:  -----> time: 0.2255244255065918
#
# TEST NO. 15
# PREFIX: ATARRDDDTDRGATUCRAUCUDUARUGATDCUT
# SECUENCE: ...
# Dynamic Recursive: 211218148664871458056685295697752535711609358648554094740301199652677704775525599474621561629950442211157014492951323542374693407141413150632989349373991797705154102669467385495961873017474210737757423709928635899874492116362003950216617364483636711416 -----> time: 0.20548152923583984
# Solve DP: 211218148664871458056685295697752535711609358648554094740301199652677704775525599474621561629950442211157014492951323542374693407141413150632989349373991797705154102669467385495961873017474210737757423709928635899874492116362003950216617364483636711416 -----> time: 0.2300713062286377
#
# TEST NO. 16
# PREFIX: AGDGADCGTDCTGCUTGRDGCCTRURDTACCGART
# SECUENCE: ...
# Dynamic Recursive: 20856904278563212518392797089744796427897861494750566091345206870452600897292010313144845790035592354273668814603916055137349316838118461737764662939910805436684680561218348222734270402466244353479834335419689273651047325024156415573273471540634276680098 -----> time: 0.22746777534484863
# Solve DP: 20856904278563212518392797089744796427897861494750566091345206870452600897292010313144845790035592354273668814603916055137349316838118461737764662939910805436684680561218348222734270402466244353479834335419689273651047325024156415573273471540634276680098 -----> time: 0.21487665176391602
#
# TEST NO. 17
# PREFIX: UADDTDUGRACCCTUTGRGDDTGAGARD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14887070655822754
# Solve DP:  -----> time: 0.22442150115966797
#
# TEST NO. 18
# PREFIX: TGDCCADDAGUCAUTTDRRDDAAUATADCCDADTA
# SECUENCE: ...
# Dynamic Recursive: 26832552941821413550447842643262813233748886417476186436422258859285760617313503872598677897063209767894473245301323414892369904070261404442125515130292399672681782345654379978545264278318677500599831870120305154768434576560232233225838471171244 -----> time: 0.22881507873535156
# Solve DP: 26832552941821413550447842643262813233748886417476186436422258859285760617313503872598677897063209767894473245301323414892369904070261404442125515130292399672681782345654379978545264278318677500599831870120305154768434576560232233225838471171244 -----> time: 0.2148432731628418
#
# TEST NO. 19
# PREFIX: ADTARCAUCDGRTUCTUTUADDGTRG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12818598747253418
# Solve DP:  -----> time: 0.22759485244750977
#
# TEST NO. 20
# PREFIX: TCCAUGAAAUUURATUTUGTRCADTUDRCRGU
# SECUENCE: ...
# Dynamic Recursive: 444706328398925627476542437858010457520430242833416020927773695493387995759024654370151389175543886292784801296948612957062708989495084723785522002471614187888799614547040283666095966859899054362212422447476793331598195498771924940275841033402614 -----> time: 0.20189547538757324
# Solve DP: 444706328398925627476542437858010457520430242833416020927773695493387995759024654370151389175543886292784801296948612957062708989495084723785522002471614187888799614547040283666095966859899054362212422447476793331598195498771924940275841033402614 -----> time: 0.21964502334594727
#
# TEST NO. 21
# PREFIX: RGGTGDCRDACUDCTGCCUAGGTGTRDC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.15563154220581055
# Solve DP:  -----> time: 0.2178182601928711
#
# TEST NO. 22
# PREFIX: AGURADDRRUDACCRRTTDRTCUTTR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.13890290260314941
# Solve DP:  -----> time: 0.2196977138519287
#
# TEST NO. 23
# PREFIX: GDGATDADGRACCTCTDDTCCTUUDDAT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.15084433555603027
# Solve DP:  -----> time: 0.21656227111816406
#
# TEST NO. 24
# PREFIX: RGCUTAAADDDRGCTGRTAURCDRUD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.13297820091247559
# Solve DP:  -----> time: 0.21897125244140625
#
# TEST NO. 25
# PREFIX: UDTUCARCDTCTUCUCDDAGAGGTGCUUTCUU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.19683027267456055
# Solve DP:  -----> time: 0.2232058048248291
#
# TEST NO. 26
# PREFIX: GRGRAGATUARDATGDRACCRUGDUCUDDTU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.18895602226257324
# Solve DP:  -----> time: 0.22186851501464844
#
# TEST NO. 27
# PREFIX: ARDDUADARGTTUDGUAAUDAADCTTURU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1720268726348877
# Solve DP:  -----> time: 0.221177339553833
#
# TEST NO. 28
# PREFIX: RURCCDCGDDRDGARDGATGDCTRTGAUTURCGGG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.23676705360412598
# Solve DP:  -----> time: 0.21375179290771484
#
# TEST NO. 29
# PREFIX: DRRAUCATDDRAUGDDAUUGDCACAA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1331188678741455
# Solve DP:  -----> time: 0.22033262252807617
#
# TEST NO. 30
# PREFIX: AGARGGCDCGCCCRAGGTDCRUDARTUDRARTU
# SECUENCE: ...
# Dynamic Recursive: 37140661649874472505082891751756430345878585662616199202037530911708636519161052465385956933429827690848421887507262567855637295285567799771588960991724000772882293543951858507735896727561124714985529804850885827249994516998964995223971805431397377860 -----> time: 0.21173572540283203
# Solve DP: 37140661649874472505082891751756430345878585662616199202037530911708636519161052465385956933429827690848421887507262567855637295285567799771588960991724000772882293543951858507735896727561124714985529804850885827249994516998964995223971805431397377860 -----> time: 0.21943426132202148
#
# TEST NO. 31
# PREFIX: ARRCCRDUUUCGAGGDGAURARATCDA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14510416984558105
# Solve DP:  -----> time: 0.21537160873413086
#
# TEST NO. 32
# PREFIX: GDGCTCATRTUAUTRRTDDRTRACUTGTG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1691598892211914
# Solve DP:  -----> time: 0.21999144554138184
#
# TEST NO. 33
# PREFIX: AUGTGTGAGADADUCDRTCURUAGDDRC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1542038917541504
# Solve DP:  -----> time: 0.2167353630065918
#
# TEST NO. 34
# PREFIX: AGAGRAAUDURGTAUCCTAGDGADC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12409830093383789
# Solve DP:  -----> time: 0.21273565292358398
#
# TEST NO. 35
# PREFIX: AGRCRGTUURTDTACDCTCURADCDCUGDUG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.17844057083129883
# Solve DP:  -----> time: 0.21992015838623047
#
# TEST NO. 36
# PREFIX: ADGTUURRGDGDGCRARTURRUGAUARDUUCGT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.2100822925567627
# Solve DP:  -----> time: 0.2176668643951416
#
# TEST NO. 37
# PREFIX: GDGTCACGTAGGURRCRTTCRTTARGCA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.15654778480529785
# Solve DP:  -----> time: 0.21770811080932617
#
# TEST NO. 38
# PREFIX: GCGCGDUTACCGDATRCGTGCRGRTUTUTADRA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.21443891525268555
# Solve DP:  -----> time: 0.22076153755187988
#
# TEST NO. 39
# PREFIX: CDDTUTCTTCCRUGDRGCAARCUUA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12416839599609375
# Solve DP:  -----> time: 0.2145979404449463
#
# TEST NO. 40
# PREFIX: AADAURTTGCGADTURDCCDGUCCG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12053990364074707
# Solve DP:  -----> time: 0.21873068809509277
#
# TEST NO. 41
# PREFIX: CTRUCGGRUDRRDGAUDGGRDAGTTRDGTD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1827695369720459
# Solve DP:  -----> time: 0.22100281715393066
#
# TEST NO. 42
# PREFIX: CTARDGGAARDUCDADTGUTDDDAADGRGC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1761159896850586
# Solve DP:  -----> time: 0.2380516529083252
#
# TEST NO. 43
# PREFIX: DCDGDDDACCUTRTGUUCRDARTGRAA
# SECUENCE: ...
# Dynamic Recursive: 904318689068556669864139289651357302054441592340241733845904021297380156797888039640465310863979038006845449422441422332128822216311768144502302381439677390045494684467530379494612240772616308203504716485041801772151702254818243422969019793032111414010368 -----> time: 0.13843774795532227
# Solve DP: 904318689068556669864139289651357302054441592340241733845904021297380156797888039640465310863979038006845449422441422332128822216311768144502302381439677390045494684467530379494612240772616308203504716485041801772151702254818243422969019793032111414010368 -----> time: 0.2224869728088379
#
# TEST NO. 44
# PREFIX: CRTAURDRDAATRUGGDAGRGUGUTD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1303391456604004
# Solve DP:  -----> time: 0.23239636421203613
#
# TEST NO. 45
# PREFIX: UDCRDARDGTGTCDTUACDDATTAGAA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14081311225891113
# Solve DP:  -----> time: 0.2241988182067871
#
# TEST NO. 46
# PREFIX: GUCGRCCUTRUTDGADATRCTCGACUDGTRTR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.19929814338684082
# Solve DP:  -----> time: 0.2297685146331787
#
# TEST NO. 47
# PREFIX: TAAGCUAARRDDAGATUCRTCGAARGDDRUCCT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.21192622184753418
# Solve DP:  -----> time: 0.22164273262023926
#
# TEST NO. 48
# PREFIX: CDTCADCTGCCGTCRGRDCACTRCDARRRD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1801753044128418
# Solve DP:  -----> time: 0.22368741035461426
#
# TEST NO. 49
# PREFIX: RGCURRUCDUUUCRAGDRAURRDADTDGDGADD
# SECUENCE: ...
# Dynamic Recursive: 39475280872825966605458286621623891624761908466756674586013398932315334595400365684398625805053367389380500984595613052499818119584373899599535685949374919377199350361263095036245055336211385516039840430910796312783434671996876311605420127604724132111164 -----> time: 0.21346402168273926
# Solve DP: 39475280872825966605458286621623891624761908466756674586013398932315334595400365684398625805053367389380500984595613052499818119584373899599535685949374919377199350361263095036245055336211385516039840430910796312783434671996876311605420127604724132111164 -----> time: 0.22948884963989258
#
# TEST NO. 50
# PREFIX: RAUDAUTCUCRTTACGRCDUDCRRCA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.13204693794250488
# Solve DP:  -----> time: 0.23240399360656738
#
# TEST NO. 51
# PREFIX: AGCRCDUCGCAUGTACDCGCRGDRGRTGA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1643998622894287
# Solve DP:  -----> time: 0.21967554092407227
#
# TEST NO. 52
# PREFIX: UTTCTCTDGGCRGCRDRGDUDDARGCR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1382617950439453
# Solve DP:  -----> time: 0.21880459785461426
#
# TEST NO. 53
# PREFIX: AGGGDDUTRDDCDDAUCATGUTGCCCUUTCU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.18654179573059082
# Solve DP:  -----> time: 0.21827077865600586
#
# TEST NO. 54
# PREFIX: URDDDDRDATDUUUTRTGAURCTTTADG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.15600228309631348
# Solve DP:  -----> time: 0.22699618339538574
#
# TEST NO. 55
# PREFIX: TAAARGTUCCGGTRDGRTRARUARUC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1340034008026123
# Solve DP:  -----> time: 0.22799324989318848
#
# TEST NO. 56
# PREFIX: GDDCTDGUGUATGRRDUUUCDTRRTRUTUA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.17503046989440918
# Solve DP:  -----> time: 0.22699856758117676
#
# TEST NO. 57
# PREFIX: GDUGGRDGTRAARRUGATRUGUCTGRA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14200520515441895
# Solve DP:  -----> time: 0.21796226501464844
#
# TEST NO. 58
# PREFIX: DDRATUDRRCGTTADCATADRCCAGGATDTDACT
# SECUENCE: ...
# Dynamic Recursive: 265222816154720931402338308130810068114220112451745476432673128979041795205313038561282464129990229834904115413968814177203517245026095014392268060619466757332241906068123445624661631950953755431863888935360130200279892653991560409721173047562286647985288 -----> time: 0.2259981632232666
# Solve DP: 265222816154720931402338308130810068114220112451745476432673128979041795205313038561282464129990229834904115413968814177203517245026095014392268060619466757332241906068123445624661631950953755431863888935360130200279892653991560409721173047562286647985288 -----> time: 0.22003507614135742
#
# TEST NO. 59
# PREFIX: ARTACDCTARDDTGURDAGDCRDGT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12299680709838867
# Solve DP:  -----> time: 0.22196507453918457
#
# TEST NO. 60
# PREFIX: ARCDRGURAUCUTCTUAUDAAGDGCAGGDURU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1980419158935547
# Solve DP:  -----> time: 0.22696280479431152
#
# TEST NO. 61
# PREFIX: TDRRGGACDUADRRTDURCRTTUGU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12203335762023926
# Solve DP:  -----> time: 0.2219998836517334
#
# TEST NO. 62
# PREFIX: UGAUCRUAUDARAACCCURUDTATARD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14600133895874023
# Solve DP:  -----> time: 0.2250051498413086
#
# TEST NO. 63
# PREFIX: URTDURUAAGDTCTTCGCDUUCDCUTCUT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.16303324699401855
# Solve DP:  -----> time: 0.22096753120422363
#
# TEST NO. 64
# PREFIX: AGURURRDGGTDTRUDCAGRTGRGAAT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14399957656860352
# Solve DP:  -----> time: 0.22499656677246094
#
# TEST NO. 65
# PREFIX: DAGGARDTGGCRDDGAAGAGTCADCCTARUTRD
# SECUENCE: ...
# Dynamic Recursive: 307321162824636105383457618043012592817153037626541295127484594287849062435450677683685430020078688462915754181656297383182165564801254441526821847208953629468808955191347384517145854588815796852541710026141655315488027774151347372120104842566385935500610 -----> time: 0.2160036563873291
# Solve DP: 307321162824636105383457618043012592817153037626541295127484594287849062435450677683685430020078688462915754181656297383182165564801254441526821847208953629468808955191347384517145854588815796852541710026141655315488027774151347372120104842566385935500610 -----> time: 0.23670411109924316
#
# TEST NO. 66
# PREFIX: DTGRGDUDTGCGDDTTDUCTTCCRUAGDRTGURT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.23096776008605957
# Solve DP:  -----> time: 0.222944974899292
#
# TEST NO. 67
# PREFIX: UDCTTCRRTDATCTDCDDCAGRUCTDDD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.16098904609680176
# Solve DP:  -----> time: 0.22325706481933594
#
# TEST NO. 68
# PREFIX: GRGARTUUUTDTCTAGURAURURCA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.12499856948852539
# Solve DP:  -----> time: 0.22597408294677734
#
# TEST NO. 69
# PREFIX: AUURCDRTGCGDRCARATTTARDTGU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1330251693725586
# Solve DP:  -----> time: 0.22700166702270508
#
# TEST NO. 70
# PREFIX: UCUDAUUGRRUURDDTTGURAAARUCDTRGD
# SECUENCE: ...
# ...
#
# TEST NO. 78
# PREFIX: AGTRADCTADCAUCURCRGUAAAATUCRAU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1808638572692871
# Solve DP:  -----> time: 0.23258376121520996
#
# TEST NO. 79
# PREFIX: UTRDAATTGATAUDGTTGAAUTDRRAAADGACU
# SECUENCE: ...
# Dynamic Recursive: 2680145564489823350692681415747494363545377249194570410417036654371010853660137130568020799133073228547853080319800646051841918223475461154773084734163902773305660096699754242221883652887957251455962646487449624123598584190378160592469582899204751140066 -----> time: 0.2290482521057129
# Solve DP: 2680145564489823350692681415747494363545377249194570410417036654371010853660137130568020799133073228547853080319800646051841918223475461154773084734163902773305660096699754242221883652887957251455962646487449624123598584190378160592469582899204751140066 -----> time: 0.23347258567810059
#
# TEST NO. 80
# PREFIX: CGUGADRCDDTRDRDDGTCTTTCTAGGDRCT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.20053529739379883
# Solve DP:  -----> time: 0.22971343994140625
#
# TEST NO. 81
# PREFIX: TGDTCDRCDDGDDCCTGDCCGCADDRGTDGTUC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.22800469398498535
# Solve DP:  -----> time: 0.22845697402954102
#
# TEST NO. 82
# PREFIX: RUDDRCTTRRDGGCRUDTCDDCTGDADGTDDU
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.20263409614562988
# Solve DP:  -----> time: 0.2265629768371582
#
# TEST NO. 83
# PREFIX: RACURAUAADGRRACADRRUTUGTDUGADDACT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.22031497955322266
# Solve DP:  -----> time: 0.22492313385009766
#
# TEST NO. 84
# PREFIX: UUCGADRCRAACRAUGGAURTAUDAC
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.13094425201416016
# Solve DP:  -----> time: 0.22559547424316406
#
# TEST NO. 85
# PREFIX: AARUCAUCTCCTUADCCCDCDTTURDDRDUCR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.2086777687072754
# Solve DP:  -----> time: 0.23283147811889648
#
# TEST NO. 86
# PREFIX: TDGUCGGRCRDRRDGAUUUUCCADRRCRT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.17239880561828613
# Solve DP:  -----> time: 0.23152852058410645
#
# TEST NO. 87
# PREFIX: RDCGRRARUDRDDCAUDTRUUGDRTUCATDTTAAU
# SECUENCE: ...
# Dynamic Recursive: 134304121394048230680101678845134303229731824507303407669259844575175942422345187208361708448818487176985885030280538675606721634202763186513480119650460532488663716869796818653238058260744635908163750671845704490771532943532676329225458658170607353430456 -----> time: 0.251615047454834
# Solve DP: 134304121394048230680101678845134303229731824507303407669259844575175942422345187208361708448818487176985885030280538675606721634202763186513480119650460532488663716869796818653238058260744635908163750671845704490771532943532676329225458658170607353430456 -----> time: 0.22121691703796387
#
# TEST NO. 88
# PREFIX: CCTACRACTDCCDUAAADGRRAAARAUDTTDT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.20850658416748047
# Solve DP:  -----> time: 0.2261056900024414
#
# TEST NO. 89
# PREFIX: ADARAGCTDCRGCDUDTCTRCUAGAGTAUUGGT
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.20844817161560059
# Solve DP:  -----> time: 0.2206892967224121
#
# TEST NO. 90
# PREFIX: ARTDTTCAGCCATACGAAUGATDTTDDGRTD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.19772720336914062
# Solve DP:  -----> time: 0.2293257713317871
#
# TEST NO. 91
# PREFIX: GTDTADAUCURRGGRTUCTRCGAGGUDR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.15285181999206543
# Solve DP:  -----> time: 0.21879315376281738
#
# TEST NO. 92
# PREFIX: RDRACDDUGACTTCUGUTCRGUURRCG
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14177989959716797
# Solve DP:  -----> time: 0.22759413719177246
#
# TEST NO. 93
# PREFIX: GCUARRGARGUCATARRACTDGDAAAD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.14596819877624512
# Solve DP:  -----> time: 0.228346586227417
#
# TEST NO. 94
# PREFIX: UCGDDUTDAGGUCRDCTCCCDGUGTCURTUD
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.1930711269378662
# Solve DP:  -----> time: 0.23122954368591309
#
# TEST NO. 95
# PREFIX: AGDGUDDTDCRARGRATTGGAAAUUDGDRR
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.18221163749694824
# Solve DP:  -----> time: 0.2254476547241211
#
# TEST NO. 96
# PREFIX: DCCUDCCCADDGCTTGDDDDGTDUA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.13007259368896484
# Solve DP:  -----> time: 0.26546216011047363
#
# TEST NO. 97
# PREFIX: CTRCTTCUTCURGCUDRTDGCDADUARRDA
# SECUENCE: ...
# Dynamic Recursive:  -----> time: 0.18990540504455566
# Solve DP:  -----> time: 0.23729300498962402
#
# TEST NO. 98
# PREFIX: UDACCUDDDRARTRGURUDCUUGTARTDDGAR
# SECUENCE: ...
# Dynamic Recursive: 12177997133334617382619559059916409265052359180903123150378475910744503592757265993123403180916619932095668044020633864062703306370126503362525684519676368188008492025637323199198818998376373687917779458329613047502459343561415327457257235068162863988 -----> time: 0.21189117431640625
# Solve DP: 12177997133334617382619559059916409265052359180903123150378475910744503592757265993123403180916619932095668044020633864062703306370126503362525684519676368188008492025637323199198818998376373687917779458329613047502459343561415327457257235068162863988 -----> time: 0.22360444068908691
#
# TEST NO. 99
# PREFIX: AUTUGRATUUACRCRCCDGUGGRUCRUDUTG
# SECUENCE: ...
# Dynamic Recursive: 139943404543629028879644290604052471573371611052678566092747732345172031733087564381050408731755180288327193290051637884162138125032481055078058217968239393458003487409504886408741058747859885594219116924011768505171990500652558529045859074373080132486 -----> time: 0.1948692798614502
# Solve DP: 139943404543629028879644290604052471573371611052678566092747732345172031733087564381050408731755180288327193290051637884162138125032481055078058217968239393458003487409504886408741058747859885594219116924011768505171990500652558529045859074373080132486 -----> time: 0.22362327575683594
#
# TEST NO. 100
# PREFIX: DGGAUCRDGRRGURDADACTCATUDGCGUCDUTUC
# SECUENCE: ...
# Dynamic Recursive: 1030291853198841618845412825961331805135407120823431149056637936619172327825465053173333218688049902496410250380357629172509145331934857517566663699304917983295412300505286155866551437485798417978231346644911507061669770319328955018517216454534 -----> time: 0.2445542812347412
# Solve DP: 1030291853198841618845412825961331805135407120823431149056637936619172327825465053173333218688049902496410250380357629172509145331934857517566663699304917983295412300505286155866551437485798417978231346644911507061669770319328955018517216454534 -----> time: 0.22630667686462402
