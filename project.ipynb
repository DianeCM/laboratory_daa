# %% [markdown]
# # El Lab (DAA Project)
#
# En un laboratorio de la BIOFAM quieren modificar genéticamente una gallina para que sea más resistente a las enfermedades. Para esto deben de cambiar la secuencia de aminoácidos presentes en su genoma. La secuencia que quieren reproducir es la de los cocodrilos, que se sabe que son animales que han existido por millones de años. Entonces, dado que una secuencia de aminoácidos se puede codificar como una secuencia de caracteres se tiene:
#
# - $T$ es la secuencia de aminoácidos de los cocodrilos (tamaño $m$)
# - $S$ es la secuencia de aminoácidos de la gallina original (tamaño $n$)
# - $A$ es la secuencia de aminoácidos de la galllina a crear (inicialmente vacía)
#
# Para lograr que la gallina modificada adquiera la resistencia de un cocodrilo se sabe que su secuencia de aminoácidos $A$, debe contener como prefijo a $T$. Como en la BIOFAM hubo recortes de presupuesto solo cuentan con una máquina que puede hacer dos modificaciones genéticas:
# 1. Extrae y elimina el primer aminoácido de $S$ y lo coloca al principio de $A$
# 2. Extrae y elimina el primer aminoácido de $S$ y lo coloca al final de $A$
#
# Encuentre la **cantidad de secuencias de operaciones posibles** tales que la gallina genéticamente modificada sea resistente a las enfermedades.
#
# Aclaraciones del problema:
# + Se debe modificar la gallina ($A$) con todos los caracteres de $S$, no basta con solo tener el prefijo, se debe llegar al final.

# %% [markdown]
# ## Soluciones
# Para una primera solución se realizó un algoritmo en el que se hace un backtrack por cada una de las operaciones posibles para crear la cadena $A$ comprobando finalmente si contiene a la cadena $T$ como prefijo dando como resultado una secuencia posible de operaciones.

# %%
def count_backtrack(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return backtrack(T, S, 0, "")
    return 0

# %% [markdown]
# Probando el algoritmo con distintos casos se obtiene como resultado:

# %%
print(count_backtrack('ACAC','ACACBCA'))
print(count_backtrack('ABAB','BABA'))
print(count_backtrack('ACABD','ACABDBCACA'))
print(count_backtrack('DBACA', 'ACABD'))
print(count_backtrack('AABBAA','BABAAA'))
print(count_backtrack('AABBAA','CHAABBAA'))
print(count_backtrack('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para el ejemplo donde $T$ (prefijo) es "ABAB" y la cadena $S$ es BABA se tiene:
# 1. B $\rightarrow$ BA $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
# 2. B $\rightarrow$ AB $\rightarrow$ BAB $\rightarrow$ BABA  (poniendo B al principio y al final)
#
# *Resultado*: 4

# %% [markdown]
# Se puede apreciar que, aunque el algoritmo resuelve el problema presenta una gran complejidad temporal, la ventaja radica en que para próximos algoritmos que tengan menor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto. Se conoce que $|T| = m$ y $|S| = n$, por tanto:
#
# \begin{equation*}
#     T(n,m) = 2 T(n-1) + 1
# \end{equation*}
#
# donde por Teorema Maestro pertence a $\theta(2^n)$

# %% [markdown]
# Se puede observar que la primera letra colocándola al principio o al final genera exactamente la misma ramificación, por lo que sería mejor evitar hacer esta segunda ramificación innecesariamente, para ello:

# %%
def count_backtrack_modified(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            cant = backtrack(T, S, index+1, char+A)
            cant += backtrack(T, S, index+1, A+char)
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando este algoritmo obtenemos los mismmos resultados, con una ligera mejora en eficiencia:

# %%
print(count_backtrack_modified('ACAC','ACACBCA'))
print(count_backtrack_modified('ACAC','CACA'))
print(count_backtrack_modified('ACABD','ACABDBCACA'))
print(count_backtrack_modified('DBACA', 'ACABD'))
print(count_backtrack_modified('AABBAA','BABAAA'))
print(count_backtrack_modified('AABBAA','CHAABBAA'))
print(count_backtrack_modified('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Como propuesta para una mejor solución a lo anterior, se realizó un memoize ya que en algunos llamados se hacían cálculos sobre subcadenas que ya se habían realizado con anterioridad, por lo que sería mejor guardar por subsecuencias de la cadena formada $A$, la subcadena restante de $S$, así como la cantidad de subsecuencias de operaciones posibles realizadas.

# %%
def count_backtrack_memoize(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        memoize = {}
        def backtrack(T:str, S:str, index:int, A:str):
            if len(S) == index:
                if T == A[0:len(T)]:return 1
                return 0
            char = S[index]
            dict_str = S[index+1:len(S)]
            word_form = char + A
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant = memoize[dict_str][word_form]
            else: 
                cant = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant}
            word_form = A + char
            if dict_str in memoize and word_form in memoize[dict_str]: 
                cant += memoize[dict_str][word_form]
            else:
                cant2 = backtrack(T, S, index+1, word_form)
                memoize[dict_str] = {word_form : cant2}
                cant += cant2
            return cant
        return 2*backtrack(T, S, 1, S[0])
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_backtrack_memoize('ACAC','ACACBCA'))
print(count_backtrack_memoize('ABAB','BABA'))
print(count_backtrack_memoize('ACABD','ACABDBCACA'))
print(count_backtrack_memoize('DBACA', 'ACABD'))
print(count_backtrack_memoize('AABBAA','BABAAA'))
print(count_backtrack_memoize('AABBAA','CHAABBAA'))
print(count_backtrack_memoize('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Aunque este algoritmo constituye una mejora significativa, sigue presentando una complejidad temporal excesiva, ya que en el peor de los casos no se repiten patrones (subcadenas) y por tanto sigue perteneciendo a $O(2^n)$ con una complejidad espacial superior. La ventaja radica en que para próximos algoritmos que tengan mejor complejidad temporal se pueda comprobar si esas soluciones planteadas van por el camino correcto.

# %% [markdown]
# Fue necesario encontrar otras vías para solucionar el ejercicio. Partiremos de los posibles casos en que puede aparecer la cadena $T$ (el prefijo), en la cadena creada (genéticamente modificada) $A$.
#
# Si se comienza a leer la cadena que se desea modificar desde atrás hacia adelante se puede observar que:
# + El último elemento podría ser colocado hacia adelante si dicho caracter es igual al primer elemento del prefijo dado que luego de él no se va a poder colocar ningún otro elemento en la cadena.
#     + A partir de este momento, el problema se reduce a calcular la cantidad de secuencias de operaciones en la que se puede formar un genoma modificado desde el inicio de la cadena hasta el caracter anterior a este elemento y el prefijo desde el segundo elemento hasta el final:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1} p_1)$ $\rightarrow$ $method(p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + El último elemento igualmente siempre se puede poner detrás
#     + Si no pertence al prefijo, el problema se reduce a generar una secuencia de operaciones tal que se obtenga una cadena a partir del resto de esta (sin dicho elemento) teniendo en cuenta todo el prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... a_j)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 ... a_{j-1})$
# + De igual forma este caracter se puede considerar poner detrás, pero si pertence al prefijo entonces debe ser el último elemento del mismo ya que es el último que se coloca, siendo el tamaño del prefijo igual al de la cadena
#     + Este problema se reduce a generar con el resto de la cadena el resto del prefijo:
#     $method(p_1 p_2 p_3 ... p_i~~~~y~~~~a_1 a_2 a_3... p_i)$ $\rightarrow$ $method(p_1 p_2 p_3 ... p_{i-1}~~~~y~~~~a_1 a_2 ... a_{j-1})$

# %%
def count_naive_recursive(T:str, S:str):
    if 0 < len(T) and len(T) <= len(S):
        def naive_recursive(S,T):
            if len(S) < len(T): return 0
            if len(S)==1: 
                if len(T)==1 and T[0]==S[0]: return 2
                return 0
            if len(T)==0 : return 0
            output = naive_recursive(S[0:len(S)-1],T)
            if S[-1]==T[0]: 
                if len(T)==1: output += 2**(len(S)-1)
                else: output += naive_recursive(S[0:len(S)-1],T[1:])
            if len(S)==len(T) and S[-1]==T[-1]: output += naive_recursive(S[0:len(S)-1],T[0:len(T)-1])
            return output
        return naive_recursive(S,T)
    return 0

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_naive_recursive('ACAC','ACACBCA'))
print(count_naive_recursive('ABAB','BABA'))
print(count_naive_recursive('ACABD','ACABDBCACA'))
print(count_naive_recursive('DBACA', 'ACABD'))
print(count_naive_recursive('AABBAA','BABAAA'))
print(count_naive_recursive('AABBAA','CHAABBAA'))
print(count_naive_recursive('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Para este algoritmo se hizo uso de la programación dinámica guardando los resultados de los cálculos anteriores siguiendo el flujo del algoritmo anterior con sus 3 índices. Por lo que este algoritmo pertenece a $O(m^2*n)$

# %%
def count_dynamic(T:str, S:str):
    if len(T) > len(S): return 0
    dp=[ [ [0 for i in range(len(S))] for i in range(len(T))] for i in range(len(T)) ]
    i=len(T)-1
    while i>=0:
        for j in range(i,len(T)):
            for k in range(len(S)):
                m=j-i
                if m > k:
                    dp[i][j][k]=0
                    continue
                if k==0:
                    if S[0] == T[i]: dp[i][j][k]=2
                    else: dp[i][j][k]=0                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   
                    continue
                if k >0 : dp[i][j][k]=dp[i][j][k-1]
                if S[k] == T[i]:
                    if m==0: dp[i][j][k]+=2**k
                    elif i<len(T)-1 and k>0: dp[i][j][k]+=dp[i+1][j][k-1]
                if k==m and S[k] == T[j] and j>0 and k>0: dp[i][j][k]+=dp[i][j-1][k-1]
        i-=1
    return dp[0][len(T)-1][len(S)-1]

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_dynamic('ACAC','ACACBCA'))
print(count_dynamic('ABAB','BABA'))
print(count_dynamic('ACABD','ACABDBCACA'))
print(count_dynamic('DBACA', 'ACABD'))
print(count_dynamic('AABBAA','BABAAA'))
print(count_dynamic('AABBAA','CHAABBAA'))
print(count_dynamic('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# Explicaciones del nuevo algoritmo!!!

# %%
def count_first_memoize(T,S):
    dp=[[[-1 for i in range(len(S))] for i in range(len(T))]for i in range(len(T))]
    return count_memoize(0,len(T)-1,len(S)-1,T,S,dp)

def count_memoize(p:int, q:int, k:int,T:str,S:str,dp):
    if dp[p][q][k]>=0: return dp[p][q][k]
    count = 0
    m=q-p+1
    for i, elem in enumerate(S[0:k+1]):
        if elem == T[p]:
            if m == 1:
                if i == 0: count+=2
                else: count += 2**i
            elif i > 0 and i >= m-1: count += count_memoize(p+1,q,i-1,T,S,dp)
            elif i > 0 and i < m-1 and T[p+i+1:q+1] == S[i+1:m]: count += count_memoize(p+1,p+i,i-1,T,S,dp)
            elif i == 0 and T[p+1:q+1] == S[1:m]: count += 2
    dp[p][q][k]=count
    return count

# %% [markdown]
# Probando el algoritmo se puede comprobar que en efecto se obtienen los mismos resultados:

# %%
print(count_first_memoize('ACAC','ACACBCA'))
print(count_first_memoize('ACAC','CACA'))
print(count_first_memoize('ACABD','ACABDBCACA'))
print(count_first_memoize('DBACA', 'ACABD'))
print(count_first_memoize('AABBAA','BABAAA'))
print(count_first_memoize('AABBAA','CHAABBAA'))
print(count_first_memoize('ACAB','BDACACBA'))
# Out:
# 12
# 4
# 20
# 4
# 12
# 4
# 8

# %% [markdown]
# En las siguientes líneas de código se realizó un generador de cadenas que juegan el rol de prefijo (cocodrilo) y genoma a modificar (gallina) haciendo particiones en el prefijo, insertando un caracter random en alguna partición e invirtiendo la secuencia. Se comprueban los resultados entre los algoritmos.

# %%
import random
import time
VOC = ["C","T","G","A","U","R","D"]

def generate_prefix(a=25,b=35):
    length = random.randint(a, b)
    prefix = ""
    while length > 0:
        letter = random.randint(0, len(VOC)-1)
        pos = random.randint(0,1)
        if pos:
            prefix += VOC[letter]
        else:
            prefix = VOC[letter] + prefix
        length-=1
    return prefix

def generate_secuence(prefix:str):
    secuence = ""
    while len(secuence) < 100:
        letter = random.randint(0, len(VOC)-1)
        partition = list(prefix.partition(random.choice(prefix)))
        pos = random.randint(0,len(partition))
        partition.insert(pos, VOC[letter])
        secuence += "".join(reversed(partition))
        secuence
    return secuence
   
TEST = 1
while TEST <= 100:
    print(f'TEST NO. {TEST}')
    prefix = generate_prefix()
    secuence = generate_secuence(prefix)
    print(f'PREFIX: {prefix} \nSECUENCE: {secuence}')
    # start = time.time()
    # c_back = count_backtrack_memoize(prefix, secuence)
    # end = time.time()
    # print(f'Backtrack Memoize: {c_back} -----> time: {end-start}')
    
    # start = time.time()
    # c_naive = count_naive_recursive(prefix, secuence)
    # end = time.time()
    # print(f'Naive Recursive: {c_naive} -----> time: {end-start}')

    start = time.time()
    c_dyn = count_dynamic(prefix, secuence)
    end = time.time()
    print(f'Dynamic Recursive: {c_dyn} -----> time: {end-start}')


    start = time.time()
    c_fmemo = count_first_memoize(prefix,secuence)
    end = time.time()
    print(f'First Memoize: {c_fmemo} -----> time: {end-start}')

    # assert c_back == c_naive == c_dyn == c_fmemo
    # assert c_naive == c_dyn == c_fmemo
    assert c_dyn == c_fmemo
    print()
    TEST+=1
# Out:
# TEST NO. 1
# PREFIX: GUDCDDRCGCURUUARCUACRUTRTGRTCCT
# SECUENCE: DDRCGCURUUARCUACRUTRTGRTCCTCGUDTDCDDRCGCURUUARCUACRUTRTGRTCCTCUGCDDRCGCURUUARCUACRUTRTGRTCCTDTGUCGCURUUARCUACRUTRTGRTCCTGRGUDCDD
# Dynamic Recursive: 7584 -----> time: 0.023027658462524414
# First Memoize: 7584 -----> time: 0.0030045509338378906
#
# TEST NO. 2
# PREFIX: CCGGTDGUTTRCURGTACUGRACGAARCDRTTGUR
# SECUENCE: GTDGUTTRCURGTACUGRACGAARCDRTTGURGCCADGUTTRCURGTACUGRACGAARCDRTTGURTCCGGUCGGTDGUTTRCURGTACUGRACGAARCDRTTGURRC
# Dynamic Recursive: 782 -----> time: 0.020999670028686523
# First Memoize: 782 -----> time: 0.003997802734375
#
# TEST NO. 3
# PREFIX: GUDCTAUTURACCUGAURCGDAURUDRCCGT
# SECUENCE: UDCTAUTURACCUGAURCGDAURUDRCCGTGGDCTAUTURACCUGAURCGDAURUDRCCGTDUGUDCTAUTURACCUGAURCGDAURUDRCCGTRGDCTAUTURACCUGAURCGDAURUDRCCGTGUG
# Dynamic Recursive: 30 -----> time: 0.022970914840698242
# First Memoize: 30 -----> time: 0.005995750427246094
#
# TEST NO. 4
# PREFIX: RTAGTADDCCDCTRUDTCCTCGTDDUUCDDT
# SECUENCE: AGTADDCCDCTRUDTCCTCGTDDUUCDDTTRRDCCDCTRUDTCCTCGTDDUUCDDTDTRTAGTAAGTADDCCDCTRUDTCCTCGTDDUUCDDTTRCUDCCDCTRUDTCCTCGTDDUUCDDTDRTAGTA
# Dynamic Recursive: 168 -----> time: 0.023010730743408203
# First Memoize: 168 -----> time: 0.005024909973144531
#
# TEST NO. 5
# PREFIX: GTRGRDTTGUURURUGDUTCTGUURTUDATT
# SECUENCE: GRDTTGUURURUGDUTCTGUURTUDATTRTGTGRDTTGUURURUGDUTCTGUURTUDATTARGTGRGRDTTGUURURUGDUTCTGUURTUDATTTGDTTGUURURUGDUTCTGUURTUDATTDGTRGR
# Dynamic Recursive: 2554 -----> time: 0.02200007438659668
# First Memoize: 2554 -----> time: 0.0060100555419921875
#
# TEST NO. 6
# PREFIX: URGTGUADCDUADRARDCDCCUURGRCGUTDDGTU
# SECUENCE: DUADRARDCDCCUURGRCGUTDDGTUCCURGTGUADDUADRARDCDCCUURGRCGUTDDGTUCDURGTGUADUCDUADRARDCDCCUURGRCGUTDDGTUDURGTGUA
# Dynamic Recursive: 21904 -----> time: 0.02995920181274414
# First Memoize: 21904 -----> time: 0.004999637603759766
#
# TEST NO. 7
# PREFIX: GTDTRTGAUTGGCCGTCDDGUDDAAAATCTUR
# SECUENCE: DTRTGAUTGGCCGTCDDGUDDAAAATCTURTGGUTGGCCGTCDDGUDDAAAATCTURAGTDTRTGGTRTGAUTGGCCGTCDDGUDDAAAATCTURDDGTDCGTCDDGUDDAAAATCTURCGTDTRTGAUTGG
# Dynamic Recursive: 430 -----> time: 0.023997068405151367
# First Memoize: 430 -----> time: 0.006000041961669922
#
# TEST NO. 8
# PREFIX: AGRUCTTAUUTGADCGRATAUARRCGTCGCR
# SECUENCE: CTTAUUTGADCGRATAUARRCGTCGCRUGAGRRUCTTAUUTGADCGRATAUARRCGTCGCRGARGRUCTTAUUTGADCGRATAUARRCGTCGCRACGRUCTTAUUTGADCGRATAUARRCGTCGCRAU
# Dynamic Recursive: 7626 -----> time: 0.022001028060913086
# First Memoize: 7626 -----> time: 0.00500178337097168
#
# TEST NO. 9
# PREFIX: URDGCTRGTCADDUDRUAUUDTRTTCCRGGCA
# SECUENCE: GCTRGTCADDUDRUAUUDTRTTCCRGGCADRURRGTCADDUDRUAUUDTRTTCCRGGCATGURDGCDGCTRGTCADDUDRUAUUDTRTTCCRGGCADRUDDUDRUAUUDTRTTCCRGGCAAURDGCTRGTCG
# Dynamic Recursive: 1436 -----> time: 0.024016141891479492
# First Memoize: 1436 -----> time: 0.005986213684082031
#
# TEST NO. 10
# PREFIX: RTTRDGDATGTTTCDUARDDCAGARUTDUCU
# SECUENCE: DATGTTTCDUARDDCAGARUTDUCUGTRTTRDDUARDDCAGARUTDUCUCRRTTRDGDATGTTTTGTTTCDUARDDCAGARUTDUCUARTTRDGDTATTRDGDATGTTTCDUARDDCAGARUTDUCUR
# Dynamic Recursive: 72216 -----> time: 0.02303457260131836
# First Memoize: 72216 -----> time: 0.0050013065338134766
#
# TEST NO. 11
# PREFIX: ACACDGDATRRCUTTUTTRDCDAUAGCTDUGTU
# SECUENCE: DATRRCUTTUTTRDCDAUAGCTDUGTUGGACACDUTTUTTRDCDAUAGCTDUGTUUACACDGDATRRCCACDGDATRRCUTTUTTRDCDAUAGCTDUGTUAG
# Dynamic Recursive: 6694 -----> time: 0.018999099731445312
# First Memoize: 6694 -----> time: 0.0039637088775634766
#
# TEST NO. 12
# PREFIX: RUCATAGUATTUTGUCTURGRTUGUACDCU
# SECUENCE: UATTUTGUCTURGRTUGUACDCUCGRUCATAUCATAGUATTUTGUCTURGRTUGUACDCUURATAGUATTUTGUCTURGRTUGUACDCUCRUAUATTUTGUCTURGRTUGUACDCURGRUCATA
# Dynamic Recursive: 122602 -----> time: 0.02000117301940918
# First Memoize: 122602 -----> time: 0.005031108856201172
#
# TEST NO. 13
# PREFIX: UCUGURURGDCRDCTADTCACUTDRU
# SECUENCE: CRDCTADTCACUTDRUDUCUGURURGTUGURURGDCRDCTADTCACUTDRUCURCUGURURGDCRDCTADTCACUTDRUUCCRDCTADTCACUTDRUDUCUGURURGT
# Dynamic Recursive: 239752 -----> time: 0.012996912002563477
# First Memoize: 239752 -----> time: 0.002004861831665039
#
# TEST NO. 14
# PREFIX: TURUDUADATCDDAUGDRCCDUAGDTDCUCT
# SECUENCE: UUADATCDDAUGDRCCDUAGDTDCUCTDTURUURUDUADATCDDAUGDRCCDUAGDTDCUCTTTRUDUADATCDDAUGDRCCDUAGDTDCUCTUATRUDUADATCDDAUGDRCCDUAGDTDCUCTUDT
# Dynamic Recursive: 0 -----> time: 0.021966218948364258
# First Memoize: 0 -----> time: 0.00503230094909668
#
# TEST NO. 15
# PREFIX: TTTRUCGDAACDDDAUCATTDUTTCCRDDCGUAC
# SECUENCE: AACDDDAUCATTDUTTCCRDDCGUACTDTTTRUCGACDDDAUCATTDUTTCCRDDCGUACAUTTTRUCGDTTRUCGDAACDDDAUCATTDUTTCCRDDCGUACRT
# First Memoize: 80 -----> time: 0.005004167556762695
#
# TEST NO. 23
# PREFIX: AARAGRCRDGRUUCARTRGARCGCCAD
# SECUENCE: GRUUCARTRGARCGCCADCDAARAGRCRAGRCRDGRUUCARTRGARCGCCADDRAAAGRCRDGRUUCARTRGARCGCCADRAARARAGRCRDGRUUCARTRGARCGCCADAG
# Dynamic Recursive: 1654430 -----> time: 0.013999223709106445
# First Memoize: 1654430 -----> time: 0.003998994827270508
#
# TEST NO. 24
# PREFIX: TUCAUGRCDARCTTACCUGGURTDT
# SECUENCE: CAUGRCDARCTTACCUGGURTDTUTAUCAUGRCDARCTTACCUGGURTDTTTARCTTACCUGGURTDTDATUCAUGRCCAUGRCDARCTTACCUGGURTDTUAT
# Dynamic Recursive: 230 -----> time: 0.01099848747253418
# First Memoize: 230 -----> time: 0.0019681453704833984
#
# TEST NO. 25
# PREFIX: AGDRRRGDTAGRURCGRAUTUADTDCDAT
# SECUENCE: AGRURCGRAUTUADTDCDATTGAGDRRRGDAGRURCGRAUTUADTDCDATTRAGDRRRGDGRAUTUADTDCDATCAGDRRRGDTAGRURAAGRURCGRAUTUADTDCDATTAGDRRRGDG
# Dynamic Recursive: 183830 -----> time: 0.01602959632873535
# First Memoize: 183830 -----> time: 0.004002809524536133
#
# TEST NO. 26
# PREFIX: CCGTUUCGAACTGUADURTAGUDDRDAGTTD
# SECUENCE: UCGTUUCGAACTGUADURTAGUDDRDAGTTDCUUCGAACTGUADURTAGUDDRDAGTTDATCCGTUUCGAACTGUADURTAGUDDRDAGTTDAGCCAACTGUADURTAGUDDRDAGTTDACCGTUUCG
# Dynamic Recursive: 0 -----> time: 0.019999980926513672
# First Memoize: 0 -----> time: 0.004999637603759766
#
# TEST NO. 27
# PREFIX: DRUCRGTUUTDURGTAGTUUCATUTAC
# SECUENCE: CRGTUUTDURGTAGTUUCATUTACUCDRGTUUCATUTACAADRUCRGTUUTDURGTCUUTDURGTAGTUUCATUTACTDRUCRGTTUUTDURGTAGTUUCATUTACGDRUCR
# Dynamic Recursive: 384 -----> time: 0.012966394424438477
# First Memoize: 384 -----> time: 0.00403594970703125
#
# TEST NO. 28
# PREFIX: RRGGRUGDUCDTRDRDCTDDRGUUCRCAUADA
# SECUENCE: GDUCDTRDRDCTDDRGUUCRCAUADADURRGGRUCDTRDRDCTDDRGUUCRCAUADADGRRGGRUGGUCDTRDRDCTDDRGUUCRCAUADADRRGGRUGRGGRUGDUCDTRDRDCTDDRGUUCRCAUADARD
# Dynamic Recursive: 147064 -----> time: 0.02299785614013672
# First Memoize: 147064 -----> time: 0.006009101867675781
#
# TEST NO. 29
# PREFIX: CDUGCUDATGURDARRDCRDAURTRAUGCCTT
# SECUENCE: UCUDATGURDARRDCRDAURTRAUGCCTTGCDUTGURDARRDCRDAURTRAUGCCTTRACDUGCUDDDUGCUDATGURDARRDCRDAURTRAUGCCTTCGTGURDARRDCRDAURTRAUGCCTTACDUGCUD
# Dynamic Recursive: 0 -----> time: 0.021990537643432617
#
# TEST NO. 37
# PREFIX: UTUGTTGDGDTRGGUTTRDCTCUCURRDUAG
# SECUENCE: GDAUTUGTTGDGDTRGGUTTRDCTCUCURRDUATTGDGDTRGGUTTRDCTCUCURRDUAGGUTUUGTTGDGDTRGGUTTRDCTCUCURRDUAGTTUTTUGTTGDGDTRGGUTTRDCTCUCURRDUAGU
# Dynamic Recursive: 0 -----> time: 0.0200345516204834
# First Memoize: 0 -----> time: 0.004997968673706055
#
# TEST NO. 38
# PREFIX: RTTGTUUDRRAADTGRAGRUTGAGTTUAR
# SECUENCE: TTGTUUDRRAADTGRAGRUTGAGTTUARRRTGTUUDRRAADTGRAGRUTGAGTTUARTRATTGTUUDRRAADTGRAGRUTGAGTTUARRRTGTUUDRRAADTGRAGRUTGAGTTUARTRG
# Dynamic Recursive: 88 -----> time: 0.01699995994567871
# First Memoize: 88 -----> time: 0.003998994827270508
#
# TEST NO. 39
# PREFIX: GCTDACUCDURGCRTCRCDGGTRATTGRCR
# SECUENCE: TDACUCDURGCRTCRCDGGTRATTGRCRTGCDACUCDURGCRTCRCDGGTRATTGRCRDTGCGCRTCRCDGGTRATTGRCRRRGCTDACUCDUTDACUCDURGCRTCRCDGGTRATTGRCRCGA
# Dynamic Recursive: 360 -----> time: 0.019967079162597656
# First Memoize: 360 -----> time: 0.00400090217590332
#
# TEST NO. 40
# PREFIX: UAUTRRTCGGRUDADDUTGUTTCADCADRR
# SECUENCE: DGGRUDADDUTGUTTCADCADRRCUAUTRRTAUTRRTCGGRUDADDUTGUTTCADCADRRUTDGRUDADDUTGUTTCADCADRRGUAUTRRTCADDUTGUTTCADCADRRTDUAUTRRTCGGRU
# Dynamic Recursive: 0 -----> time: 0.01999950408935547
# First Memoize: 0 -----> time: 0.004000186920166016
#
# TEST NO. 41
# PREFIX: RDCDRGUDRGGCDUGUUDADGRURRURC
# SECUENCE: DRGGCDUGUUDADGRURRURCAURDCDRGCDRGUDRGGCDUGUUDADGRURRURCDCRUDRGGCDUGUUDADGRURRURCGRDCDRCDRGUDRGGCDUGUUDADGRURRURCCRDR
# Dynamic Recursive: 316570 -----> time: 0.016999483108520508
# First Memoize: 316570 -----> time: 0.004001617431640625
#
# TEST NO. 42
# PREFIX: CGAUCCCDDDRTAGRUDCTAGGAAAAAARCGGR
# SECUENCE: TAGRUDCTAGGAAAAAARCGGRRCGAUCCCDDDUTAGRUDCTAGGAAAAAARCGGRRRCGAUCCCDDDGTAGRUDCTAGGAAAAAARCGGRRCGAUCCCDDD
# Dynamic Recursive: 29664 -----> time: 0.019032955169677734
# First Memoize: 29664 -----> time: 0.0029997825622558594
#
# TEST NO. 43
# PREFIX: UCTGRCGRRTDURCGAUUCUGGUUGD
# SECUENCE: TGRCGRRTDURCGAUUCUGGUUGDDCURCGRRTDURCGAUUCUGGUUGDAGUCTCTGRCGRRTDURCGAUUCUGGUUGDUCRCGRRTDURCGAUUCUGGUUGDGRUCT
# Dynamic Recursive: 342 -----> time: 0.012968301773071289
# First Memoize: 342 -----> time: 0.0020313262939453125
#
# TEST NO. 44
# PREFIX: ADATUTRRDGRRCADUGGCTDDDUUUTRRUD
# SECUENCE: RDGRRCADUGGCTDDDUUUTRRUDRRADATUTATUTRRDGRRCADUGGCTDDDUUUTRRUDDAUATUTRRDGRRCADUGGCTDDDUUUTRRUDRDATRRDGRRCADUGGCTDDDUUUTRRUDUGADAT
# Dynamic Recursive: 92332 -----> time: 0.021001577377319336
# First Memoize: 92332 -----> time: 0.003998279571533203
#
# TEST NO. 45
# PREFIX: RGARCRADTGGDDCRRAUDCATGRAUA
# SECUENCE: RCRADTGGDDCRRAUDCATGRAUAARGCCARCRADTGGDDCRRAUDCATGRAUAGRGARCRADTGGDDCRRAUDCATGRAUAARRCRADTGGDDCRRAUDCATGRAUAUARG
# Dynamic Recursive: 3632 -----> time: 0.014000415802001953
# First Memoize: 3632 -----> time: 0.0029952526092529297
#
# TEST NO. 46
# PREFIX: CTRRUGRRGUGCAAURATDCURRCDUG
# SECUENCE: RUGRRGUGCAAURATDCURRCDUGGRCTTRRUGRRGUGCAAURATDCURRCDUGTCCURRCDUGDCTRRUGRRGUGCAAURATRDRUGRRGUGCAAURATDCURRCDUGRCT
# Dynamic Recursive: 664 -----> time: 0.014003992080688477
# First Memoize: 664 -----> time: 0.00400090217590332
#
# TEST NO. 47
# PREFIX: DCATDCDUCUGTDATCTTCCDGDDRC
# SECUENCE: ATDCDUCUGTDATCTTCCDGDDRCCCDATDCDUCUGTDATCTTCCDGDDRCCDTCRDCATDCDUCUGTDATCTTCCDGDDADCDUCUGTDATCTTCCDGDDRCTCDCA
# Dynamic Recursive: 588 -----> time: 0.012001752853393555
# First Memoize: 588 -----> time: 0.0030007362365722656
#
# TEST NO. 48
# PREFIX: TTDGGUATAGUDTGURDDGRRURUUUGTCCTDD
# SECUENCE: UDDGRRURUUUGTCCTDDRTTDGGUATAGUDTGUDGGUATAGUDTGURDDGRRURUUUGTCCTDDDTTTDGGUATAGUDTGURDDGRRURUUUGTCCTDDTA
# Dynamic Recursive: 0 -----> time: 0.022961854934692383
# First Memoize: 0 -----> time: 0.004001140594482422
#
# TEST NO. 49
# PREFIX: TTTACGDDTUDUTRRCRGDUTGTAGGTUATRGA
# SECUENCE: RCRGDUTGTAGGTUATRGACRTTTACGDDTUDUTTTACGDDTUDUTRRCRGDUTGTAGGTUATRGATTCGDDTUDUTRRCRGDUTGTAGGTUATRGAADTTT
# Dynamic Recursive: 48384 -----> time: 0.019034385681152344
# First Memoize: 48384 -----> time: 0.003966808319091797
#
# TEST NO. 50
# PREFIX: DGUUTRCTDDTGCGTTGTGGDDGUGDUUDDAC
# SECUENCE: GUUTRCTDDTGCGTTGTGGDDGUGDUUDDACUDTGUUTRCTDDTGCGTTGTGGDDGUGDUUDDACDRCTDDTGCGTTGTGGDDGUGDUUDDACTDGUUTTDDTGCGTTGTGGDDGUGDUUDDACCUDGUUTR
# Dynamic Recursive: 50 -----> time: 0.024000167846679688
# First Memoize: 50 -----> time: 0.004033803939819336
#
# TEST NO. 51
# First Memoize: 23931440 -----> time: 0.004999876022338867
#
# TEST NO. 65
# PREFIX: UATCGTTDUDTCUATUDCDAUCGACDTCUTTUDD
# SECUENCE: UDTCUATUDCDAUCGACDTCUTTUDDRDUATCGTTUUDTCUATUDCDAUCGACDTCUTTUDDDUATCGTTATCGTTDUDTCUATUDCDAUCGACDTCUTTUDDUT
# Dynamic Recursive: 20396 -----> time: 0.020999908447265625
# First Memoize: 20396 -----> time: 0.005000591278076172
#
# TEST NO. 66
# PREFIX: TUGRGTDGUCTACCTURTACRCUGC
# SECUENCE: DRGTDGUCTACCTURTACRCUGCGTURGTDGUCTACCTURTACRCUGCGTUGDTACCTURTACRCUGCCTUGRGTDGUGRGTDGUCTACCTURTACRCUGCGUT
# Dynamic Recursive: 0 -----> time: 0.01100015640258789
# First Memoize: 0 -----> time: 0.002006053924560547
#
# TEST NO. 67
# PREFIX: UDCCTCAGCCUCURUDGUGTUCTCRUDUGGTAA
# SECUENCE: DDCCTCAGCCUCURUDGUGTUCTCRUDUGGTAAURDCCTCAGCCUCURUDGUGTUCTCRUDUGGTAAUCCUCURUDGUGTUCTCRUDUGGTAAGGUDCCTCA
# Dynamic Recursive: 0 -----> time: 0.018999814987182617
# First Memoize: 0 -----> time: 0.003998994827270508
#
# TEST NO. 68
# PREFIX: CUDACGDRGDTDRCGGDAUDCDDTUACGUCARGCU
# SECUENCE: UDACGDRGDTDRCGGDAUDCDDTUACGUCARGCUCGACGDRGDTDRCGGDAUDCDDTUACGUCARGCUDUCUACGDRGDTDRCGGDAUDCDDTUACGUCARGCUDACU
# Dynamic Recursive: 30 -----> time: 0.023031234741210938
# First Memoize: 30 -----> time: 0.00400233268737793
#
# TEST NO. 69
# PREFIX: GCCCACRCAUUDCGTTTACDCUATDU
# SECUENCE: CCACRCAUUDCGTTTACDCUATDUCGAUDCGTTTACDCUATDUUGCCCACRCARUDCGTTTACDCUATDUCUGCCCACRCAGCRCAUUDCGTTTACDCUATDUAGCCC
# Dynamic Recursive: 368 -----> time: 0.011997461318969727
# First Memoize: 368 -----> time: 0.003971576690673828
#
# TEST NO. 70
# PREFIX: TTCCGAGGRDGRDRUDCRURCTGGDURGAAU
# SECUENCE: AGGRDGRDRUDCRURCTGGDURGAAURGTTCCDCRURCTGGDURGAAUCUTTCCGAGGRDGRDRCGGRDGRDRUDCRURCTGGDURGAAUATTCCGDCRURCTGGDURGAAUUTTCCGAGGRDGRDRC
# Dynamic Recursive: 5120 -----> time: 0.021028757095336914
# First Memoize: 5120 -----> time: 0.004002094268798828
#
# TEST NO. 71
# PREFIX: TDARTACGGGGTRTCAGGGTURDAD
# SECUENCE: CARTACGGGGTRTCAGGGTURDADDTGGGTRTCAGGGTURDADGATDARTACARTACGGGGTRTCAGGGTURDADDTTDARTACGGGGTRTCAGGGTURDADDT
# Dynamic Recursive: 0 -----> time: 0.012989282608032227
# First Memoize: 0 -----> time: 0.0030107498168945312
#
# TEST NO. 72
# PREFIX: RCAUCAUATTRRUARRRTCAURCACCU
# SECUENCE: RAUCAUATTRRUARRRTCAURCACCUCRUCAUATTRRUARRRTCAURCACCUARCTCAUCAUATTRRUARRRTCAURCACCURTDCAUATTRRUARRRTCAURCACCUURCA
# Dynamic Recursive: 0 -----> time: 0.015969276428222656
# First Memoize: 0 -----> time: 0.0049974918365478516
#
# TEST NO. 73
# PREFIX: TGRUAGUTUGCARTTDTCACDTRACGG
# SECUENCE: DRUAGUTUGCARTTDTCACDTRACGGGTDGRUAGUTUGCARTTDTCACDTRACGGTAGUTUGCARTTDTCACDTRACGGUTGRTAGUTUGCARTTDTCACDTRACGGUTGRT
# Dynamic Recursive: 3180288 -----> time: 0.014999628067016602
# First Memoize: 3180288 -----> time: 0.0030002593994140625
#
# TEST NO. 74
# PREFIX: RGGATRRRCURGRRDGUARRGTACTGRGGDCG
# SECUENCE: GATRRRCURGRRDGUARRGTACTGRGGDCGGURAGGATRRRCURGRRDGUARRGTACTGRGGDCGRUGGATRRRCURGRRDGUARRGTACTGRGGDCGRRGATRRRCURGRRDGUARRGTACTGRGGDCGGR
# Dynamic Recursive: 908 -----> time: 0.02599954605102539
# First Memoize: 908 -----> time: 0.0070002079010009766
#
# TEST NO. 75
# PREFIX: ADUGGACUTRTCRGUGATTGARURTGATCUCCUG
# SECUENCE: RTCRGUGATTGARURTGATCUCCUGUTADUGGACUGGACUTRTCRGUGATTGARURTGATCUCCUGUUADDUGGACUTRTCRGUGATTGARURTGATCUCCUGAT
# Dynamic Recursive: 1900 -----> time: 0.022001981735229492
# First Memoize: 1900 -----> time: 0.0039980411529541016
#
# TEST NO. 76
# PREFIX: RRRGDGUTRGUADUAUACTGTUGDDGRDRGGGA
# SECUENCE: DRRGDGUTRGUADUAUACTGTUGDDGRDRGGGARDGUTRGUADUAUACTGTUGDDGRDRGGGAGRRRCDGUTRGUADUAUACTGTUGDDGRDRGGGAGRRRR
# Dynamic Recursive: 0 -----> time: 0.018999576568603516
# First Memoize: 0 -----> time: 0.005000591278076172
#
# TEST NO. 77
# PREFIX: UCRTGUCCTDUCACATCAGCGAGUDA
# SECUENCE: CATCAGCGAGUDAUAUCRTGUCCTDUCCATCAGCGAGUDAAUCRTGUCCTDUCURTGUCCTDUCACATCAGCGAGUDACRUCATCAGCGAGUDAAAUCRTGUCCTDUC
# Dynamic Recursive: 12508 -----> time: 0.01300048828125
# First Memoize: 12508 -----> time: 0.0019996166229248047
#
# TEST NO. 78
# PREFIX: RATCGTTDAUTCCTGUGTTUUCCARUCT
# SECUENCE: TCCTGUGTTUUCCARUCTAURATCGTTDAATCGTTDAUTCCTGUGTTUUCCARUCTDRGTTDAUTCCTGUGTTUUCCARUCTTCRATAGTTDAUTCCTGUGTTUUCCARUCTCRAT
# Dynamic Recursive: 466128 -----> time: 0.017000436782836914
# First Memoize: 466128 -----> time: 0.0029993057250976562
#
# TEST NO. 79
# PREFIX: CDCCCDGDGRAATRAGGGTUGCUTTDTRAGARUDG
# SECUENCE: GCUTTDTRAGARUDGTUCDCCCDGDGRAATRAGGGTDGRAATRAGGGTUGCUTTDTRAGARUDGGTCDCCCDDGRAATRAGGGTUGCUTTDTRAGARUDGDGCDCCCD
